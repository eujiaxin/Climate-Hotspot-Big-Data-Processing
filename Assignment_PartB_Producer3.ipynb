# %% [markdown]
# # FIT3182 Assignment Part B
#
# ### Eu Jia Xin (30881676)

# %% [markdown]
# ## Task 1c:
#
# ### Event Producer 3
# Write a python program that loads all the data from `hotspot_TERRA_streaming.csv` and randomly (with replacement) feeds the data to the stream every 2 seconds. TERRA is another satellite from NASA that reports latitude, longitude, confidence and surface temperature of a location. You will need to append additional information such as **producer information** to identify
# the producer and **created date & time**.

# %%
# import relevant libraries 

from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import pandas as pd
import datetime
import json
from pprint import pprint

ENCODING_FORMAT = 'utf-8'
HOTSPOT_TERRA_STREAMING_PATH = 'datasets/hotspot_TERRA_streaming.csv'

# %%
def get_hotspot_terra_streaming_data():
    """
    Convert the CSV file into pandas dataframe, pre-process then convert into JSON.
    """
    # get hotspot terra data as pandas dataframe
    hotspot_terra_streaming_df = pd.read_csv(HOTSPOT_TERRA_STREAMING_PATH)

    # convert hotspot data to a list of JSON objects
    result = hotspot_terra_streaming_df.to_json(orient="records")
    hotspot_terra_streaming_json = json.loads(result)
    
    return hotspot_terra_streaming_json

# check for first record - looks good (additional info to be added in main function)
get_hotspot_terra_streaming_data()[0]
# Out:
# {'latitude': -37.966,
#  'longitude': 145.051,
#  'confidence': 78,
#  'surface_temperature_celcius': 68}

# %%
def publish_message(producer_instance, topic_name, data):
    try:
        # directly send data as json because we already specify the JSON serializer in KafkaProducer 
        producer_instance.send(topic_name, value=data)
        print('Message published successfully. ' + str(data))
    except Exception as e:
        print('Exception in publishing message.')
        print(str(e))

# %%
def connect_kafka_producer():
    """
    KafkaProducer has extra value_serializer to properly handle json message. 
    Reference: https://kafka-python.readthedocs.io/en/master/usage.html?highlight=json#kafkaproducer
    """
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda m: json.dumps(m).encode('ascii'), # produce json messages 
                                  api_version=(0, 10))
    except Exception as e:
        print('Exception while connecting Kafka.')
        print(str(e))
    finally:
        return _producer

# %%
if __name__ == '__main__':
    """
    Declare topic and producer instance.
    Randomly gets a hotspot record from hotspot_terra_streaming.csv, and appends the appropriate date and producer id.
    Waits for 2 seconds before publishing next hotspot record.
    To stop the publishing, can interrupt the kernel to trigger a KeyboardInterrupt. 
    
    Handling the time increment:
    Since data uploaded every 2 seconds, and every 10s = 1 day, this means that 5 records are produced in a day.
    To simulate this, each record would take 24/5 = 4.8 hours to be published. 
    """
    topic = 'Hotspot_TERRA'
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    hotspot_terra_streaming_data = get_hotspot_terra_streaming_data()
    
    # based on requirements, our first created date should be the latest date from climate_historic
    date = datetime.datetime(2021, 12, 31)
    
    # add some time to the date before publishing first record (so that it will start on the next day)
    date += datetime.timedelta(hours=19.2)
    
    while True:
        
        for _ in range(5):
            
            date += datetime.timedelta(hours=24/5)
            
            i = random.randrange(0, len(hotspot_terra_streaming_data)) # [0, 2623)

            random_hotspot_terra_streaming_data = hotspot_terra_streaming_data[i]

            # append additional information
            random_hotspot_terra_streaming_data['time'] = date.time().strftime("%H:%M")
            
            random_hotspot_terra_streaming_data['producer_id'] = 'producer_hotspot_terra'

            publish_message(producer_instance=producer, topic_name=topic, data=random_hotspot_terra_streaming_data)

            # 2 seconds interval of publishing data
            sleep(2)
# Out:
# Publishing records..
# Message published successfully. {'latitude': -37.9284, 'longitude': 143.108, 'confidence': 92, 'surface_temperature_celcius': 70, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.
 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -38.0395, 'longitude': 146.0486, 'confidence': 83, 'surface_temperature_celcius': 63, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.7483, 'longitude': 142.9052, 'confidence': 76, 'surface_temperature_celcius': 54, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.4169, 'longitude': 144.2994, 'confidence': 97, 'surface_temperature_celcius': 81, 'time': '04:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -35.9197, 'longitude': 143.9757, 'confidence': 85, 'surface_temperature_celcius': 59, 'time': '09:36', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.0782, 'longitude': 145.3625, 'confidence': 91, 'surface_temperature_celcius': 68, 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.8359, 'longitude': 146.6448, 'confidence': 96, 'surface_temperature_celcius': 78, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.401, 'longitude': 145.5113, 'confidence': 77, 'surface_temperature_celcius': 55, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.982, 'longitude': 143.6422, 'confidence': 56, 'surface_temperature_celcius': 42, 'time': '04:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.5963, 'longitude': 144.0066, 'confidence': 51, 'surface_temperature_celcius': 38, 'time': '09:36', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.3735, 'longitude': 145.886, 'confidence': 87, 'surface_temperature_celcius': 96, 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.0966, 'longitude': 142.3635, 'confidence': 86, 'surface_temperature_celcius': 61, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.3864, 'longitude': 141.3034, 'confidence': 80, 'surface_temperature_celcius': 54, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.2115, 'longitude': 141.6878, 'confidence': 77, 'surface_temperature_celcius': 50, 'time': '04:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.863, 'longitude': 144.17, 'confidence': 86, 'surface_temperature_celcius': 60, 'time': '09:36', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.4113, 'longitude': 141.1671, 'confidence': 82, 'surface_temperature_celcius': 55, 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.3492, 'longitude': 145.9333, 'confidence': 73, 'surface_temperature_celcius': 47, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.9184, 'longitude': 142.5436, 'confidence': 50, 'surface_temperature_celcius': 42, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.436, 'longitude': 148.088, 'confidence': 86, 'surface_temperature_celcius': 76, 'time': '04:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.0769, 'longitude': 141.042, 'confidence': 93, 'surface_temperature_celcius': 72, 'time': '09:36', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.0942, 'longitude': 145.5705, 'confidence': 61, 'surface_temperature_celcius': 53, 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.6387, 'longitude': 142.9032, 'confidence': 87, 'surface_temperature_celcius': 88, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -38.2946, 'longitude': 145.9538, 'confidence': 74, 'surface_temperature_celcius': 48, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.8641, 'longitude': 143.4276, 'confidence': 100, 'surface_temperature_celcius': 51, 'time': '04:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.7199, 'longitude': 142.5844, 'confidence': 63, 'surface_temperature_celcius': 56, 'time': '09:36', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.4216, 'longitude': 141.2799, 'confidence': 60, 'surface_temperature_celcius': 40, 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.7052, 'longitude': 144.6926, 'confidence': 72, 'surface_temperature_celcius': 46, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -37.864, 'longitude': 144.174, 'confidence': 58, 'surface_temperature_celcius': 41, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -35.7542, 'longitude': 142.5039, 'confidence': 64, 'surface_temperature_celcius': 42, 'time': '04:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.0925, 'longitude': 145.7774, 'confidence': 84, 'surface_temperature_celcius': 58, 'time': '09:36', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.7076, 'longitude': 142.5982, 'confidence': 73, 'surface_temperature_celcius': 47, 'time': '14:24', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -36.4306, 'longitude': 141.5645, 'confidence': 74, 'surface_temperature_celcius': 48, 'time': '19:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. {'latitude': -38.0781, 'longitude': 143.9374, 'confidence': 80, 'surface_temperature_celcius': 54, 'time': '00:00', 'producer_id': 'producer_hotspot_terra'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f7c49e6a84a8> in <module>
#      41
#      42             # 2 seconds interval of publishing data
# ---> 43             sleep(2)
#
# KeyboardInterrupt:
