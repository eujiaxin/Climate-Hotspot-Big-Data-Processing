# %% [markdown]
# # FIT3182 Assignment Part B
#
# ### Eu Jia Xin (30881676)

# %% [markdown]
# ## Task 1d:
#
# ### Streaming Application
# Write a streaming application using the Apache Spark Structured Streaming API which processes data in batches of 10 seconds. The streaming application will receive streaming data from all three producers and processes it as required.

# %%
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StringType, DoubleType, DateType, IntegerType
from pyspark.sql.streaming import StreamingQueryException
from pyspark.sql.functions import col, from_json

import datetime
import json
import pprint
import time
import geohash2
from pprint import pprint

CLIMATE_TOPIC = 'Climate'
HOTSPOT_AQUA_TOPIC = 'Hotspot_AQUA'
HOTSPOT_TERRA_TOPIC = 'Hotspot_TERRA'
DB_NAME = 'fit3182_assignment_db'

# %%
# Create Spark context and streaming context

# create spark session
spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('Spark Streaming from Kafka into MongoDB')
    .getOrCreate()
)

# %%
# create streaming dataframe with optionss providing the bootstrap server and topic name

topics = ",".join([CLIMATE_TOPIC, HOTSPOT_AQUA_TOPIC, HOTSPOT_TERRA_TOPIC])

climate_topic_stream_df = (
    spark.readStream.format('kafka') # specify source
    .option('kafka.bootstrap.servers', 'localhost:9092') # options
    .option('subscribe', topics) # multiple topics are subscribed here
    .load()
)

# %%
climate_topic_stream_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
schema = (
    StructType().add("latitude", DoubleType()).add("longitude", DoubleType()).add('air_temperature_celcius', IntegerType())
                    .add('relative_humidity', DoubleType()).add('windspeed_knots', DoubleType()).add('max_wind_speed', DoubleType())
                    .add('precipitation', DoubleType()).add('precipitation_flag', StringType()).add('GHI', IntegerType())
                    .add('date', DateType()).add('time', StringType()).add('producer_id', StringType())
                    .add('confidence', IntegerType()).add('surface_temperature_celcius', IntegerType())
)

# %%
climate_output_stream_df = (
    climate_topic_stream_df.select(
        from_json(col("value").cast("string"), schema).alias("climate_parsed_value"))
        .select(col("climate_parsed_value.*"))
)

# %%
def foreach_batch_function(df, epoch_id):
    # transform and write batchDF
    batch_records = []
    for row in df.collect():
        row_json = row.asDict(True)
        batch_records.append(row)
    
    cleaned_record = streaming_data_handler(batch_records)

    if cleaned_record is None:
        return 
    
    # insert cleaned_record into mongodb
    mongo_client = MongoClient(host='localhost', port=27017)
    db = mongo_client['fit3182_assignment_db']
    collection = db.climate
    
    inserted_res = collection.insert_one(cleaned_record)
    print(inserted_res)
    pprint(cleaned_record)
    print()
    
    mongo_client.close()

# %%
db_writer = (
    climate_output_stream_df
    .writeStream
    .outputMode('append')
    .foreachBatch(foreach_batch_function)
    .trigger(processingTime='10 seconds') # batch and process data in micro-batch intervals of 10 seconds 
)

writer = db_writer

# %% [markdown]
# The following are helper functions to process streaming data and clean it before adding to MongoDB.

# %%
def get_geohash(lat, long, precision=3):
    """
    Return geohash characters based on a location. Number of characters determined by precision argument.
    """
    chars = geohash2.encode(lat, long, precision=precision)
    return chars

def clean_record(original):
    """
    Given original streaming data, it is cleaned to fit the designed data model back in Task A.
    Note that hotspots now has an additional 'cause' attribute based on requirements.
    """
    climate = {}
    
    climate['date'] = datetime.datetime.combine(original['date'], datetime.datetime.min.time())
    climate['air_temperature_celcius'] = original['air_temperature_celcius']
    climate['max_wind_speed'] = original['max_wind_speed']
    climate['precipitation'] = original['precipitation']
    climate['precipitation_flag'] = original['precipitation_flag']
    climate['relative_humidity'] = original['relative_humidity']
    climate['station'] = original['station']
    climate['windspeed_knots'] = original['windspeed_knots']
    climate['GHI'] = original['GHI']
    
    if 'hotspot' in original:
        climate['hotspot'] = []
        for h in original['hotspot']:
            hotspot = dict()
            hour, minute = h['time'].split(':')
            hour, minute = int(hour), int(minute)
            hotspot['datetime'] = datetime.datetime.combine(original['date'], datetime.time(hour=hour, minute=minute))
#             hotspot['datetime'] = datetime.datetime.strptime(hotspot['datetime'], '%Y-%m-%dT%H:%M:%S')
            hotspot['latitude'] = h['latitude']
            hotspot['longitude'] = h['longitude']
            hotspot['confidence'] = h['confidence']
            hotspot['surface_temperature_celcius'] = h['surface_temperature_celcius']
            hotspot['cause'] = h['cause']
            climate['hotspot'].append(hotspot)
    
    return climate

def get_avg_confidence(hotspot1, hotspot2):
    return (hotspot1['confidence'] + hotspot2['confidence']) / 2

def get_avg_surface_temperature_celcius(hotspot1, hotspot2):
    return (hotspot1['surface_temperature_celcius'] + hotspot2['surface_temperature_celcius']) / 2

def merge_hotspots(aqua_hotspots, terra_hotspots):
    """
    Group hotspots based on location using geohash, for same locations,
    take the average surface temperature and confidence and save as a fire event.
    
    """
    hotspots = []
    
    # check if there are empty hotspots
    if len(aqua_hotspots) + len(terra_hotspots) == 0:
        return hotspots
    if len(aqua_hotspots) == 0:
        return terra_hotspots
    if len(terra_hotspots) == 0:
        return aqua_hotspots
    
    # receive data from 2 different satellites aqua and terra -> check for geohash precision 5 for same location
    # take average surface temp and confidence from the 2 same locations if merged
    used_hotspots = []
    merged_hotspots = []
    for aqua_hotspot in aqua_hotspots:
        found_terra = False
        for terra_hotspot in terra_hotspots:
            if aqua_hotspot['geohash5'] == terra_hotspot['geohash5']:
                # geohash precision 5 -> same location, can merge
                merged_hotspot = aqua_hotspot
                merged_hotspot['confidence'] = get_avg_confidence(aqua_hotspot, terra_hotspot)
                merged_hotspot['surface_temperature_celcius'] = get_avg_surface_temperature_celcius(aqua_hotspot, terra_hotspot)                
                merged_hotspots.append(merged_hotspot)
                used_hotspots.append(terra_hotspot)
                found_terra = True
            
        if not found_terra:
            # cant find any similar terra hotspots, add aqua_hotspot without merging
            merged_hotspots.append(aqua_hotspot)
    
    for terra_hotspot in terra_hotspots:
        # append terra hotspots that were not used from merging with aqua earlier
        if terra_hotspot not in used_hotspots:
            merged_hotspots.append(terra_hotspot)
            
    return merged_hotspots

# %%
def streaming_data_handler(data_lst):
    """
    data_lst holds the rows from all 3 producers in a single batch (10 seconds).
    The handler will process each row by identifying which datastream it is from based on the producer id, 
    then appropriately handle the climate and hotspots before cleaning.
    """
    hotspots = []
    climate = {}
    aqua_hotspots = []
    terra_hotspots = []
    
    for row in data_lst:
        record = row.asDict(True)
        # prepare geohash attribute 
        record['geohash3'] = get_geohash(record['latitude'], record['longitude'],3)
        record['geohash5'] = get_geohash(record['latitude'], record['longitude'], 5)
        
        if record['producer_id'] == 'producer_climate':
            climate = record
            climate['station'] = 948701 # add station for Task A data model requirements
            climate['hotspot'] = []
            
        elif record['producer_id'] == 'producer_hotspot_aqua':
            aqua_hotspots.append(record)
        elif record['producer_id'] == 'producer_hotspot_terra':
            terra_hotspots.append(record)
    
    hotspots = merge_hotspots(aqua_hotspots, terra_hotspots)
    
    # if streaming application has data from only 1 producer (Producer 1: Climate), it implies
    # that there was no fire at that time and we can store the climate data into MongoDB straight away.
    if len(climate) == 0:
        return
    elif len(hotspots) == 0:
        # only have climate data
        return clean_record(climate)
    else:
        # have both climate and hotspot
        for hotspot in hotspots:
            # check if climate and hotspot location - if not close, ignore hotspot.
            if climate['geohash3'] == hotspot['geohash3']:
                # for valid hotspots that are close, must determine cause of fire
                if climate['air_temperature_celcius'] > 20 and climate['GHI'] > 180:
                    hotspot['cause'] = 'natural'
                else:
                    hotspot['cause'] = 'other'
                
                # embed hotspot into climate
                climate['hotspot'].append(hotspot)
    
    cleaned_climate = clean_record(climate)
    return cleaned_climate

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopped query')
except StreamingQueryException as exc:
    print(exc)
finally:
    query.stop()
# Out:
# <pymongo.results.InsertOneResult object at 0x7f69bc490fc0>
# {'GHI': 147,
#  '_id': ObjectId('6282940500d4d500b4235a25'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2022, 1, 9, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 84,
#               'datetime': datetime.datetime(2022, 1, 9, 4, 48),
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 8.9}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc463680>
# {'GHI': 102,
#  '_id': ObjectId('6282940f00d4d500b4235a27'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 1, 10, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 58.0,
#               'datetime': datetime.datetime(2022, 1, 10, 19, 12),
#               'latitude': -37.7379,
#               'longitude': 143.1706,
#               'surface_temperature_celcius': 40.0},
#              {'cause': 'other',
#               'confidence': 71,
#               'datetime': datetime.datetime(2022, 1, 10, 19, 12),
#               'latitude': -36.9299,
#               'longitude': 142.9671,
#               'surface_temperature_celcius': 46}],
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 6.4}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc463880>
# {'GHI': 120,
#  '_id': ObjectId('6282941900d4d500b4235a29'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2022, 1, 11, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 100,
#               'datetime': datetime.datetime(2022, 1, 11, 9, 36),
#               'latitude': -37.396,
#               'longitude': 148.086,
#               'surface_temperature_celcius': 65},
#              {'cause': 'other',
#               'confidence': 87,
#               'datetime': datetime.datetime(2022, 1, 11, 14, 24),
#               'latitude': -37.569,
#               'longitude': 148.024,
#               'surface_temperature_celcius': 60},
#              {'cause': 'other',
#               'confidence': 78,
#               'datetime': datetime.datetime(2022, 1, 11, 9, 36),
#               'latitude': -36.851,
#               'longitude': 148.117,
#               'surface_temperature_celcius': 46}],
#  'max_wind_speed': 22.0,
#  'precipitation': 0.03,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 13.7}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc4655c0>
# {'GHI': 154,
#  '_id': ObjectId('6282942300d4d500b4235a2b'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 1, 12, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.3,
#  'station': 948701,
#  'windspeed_knots': 5.8}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc444880>
# {'GHI': 136,
#  '_id': ObjectId('6282942d00d4d500b4235a2d'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 13, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 100,
#               'datetime': datetime.datetime(2022, 1, 13, 19, 12),
#               'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.03,
#  'precipitation_flag': 'G',
#  'relative_humidity': 50.9,
#  'station': 948701,
#  'windspeed_knots': 12.9}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc4909c0>
# {'GHI': 105,
#  '_id': ObjectId('6282943700d4d500b4235a2f'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2022, 1, 14, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 84,
#               'datetime': datetime.datetime(2022, 1, 14, 0, 0),
#               'latitude': -35.4993,
#               'longitude': 143.3105,
#               'surface_temperature_celcius': 57}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 47.9,
#  'station': 948701,
#  'windspeed_knots': 6.7}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc490d80>
# {'GHI': 143,
#  '_id': ObjectId('6282944000d4d500b4235a31'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 1, 15, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 52.5,
#  'station': 948701,
#  'windspeed_knots': 6.7}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc463bc0>
# {'GHI': 66,
#  '_id': ObjectId('6282944b00d4d500b4235a33'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2022, 1, 16, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 81,
#               'datetime': datetime.datetime(2022, 1, 16, 19, 12),
#               'latitude': -36.3479,
#               'longitude': 145.5258,
#               'surface_temperature_celcius': 55}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'relative_humidity': 37.2,
#  'station': 948701,
#  'windspeed_knots': 6.2}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc4f9d80>
# {'GHI': 109,
#  '_id': ObjectId('6282945500d4d500b4235a35'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2022, 1, 17, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 87,
#               'datetime': datetime.datetime(2022, 1, 17, 9, 36),
#               'latitude': -36.4339,
#               'longitude': 141.5458,
#               'surface_temperature_celcius': 62}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc463a40>
# {'GHI': 131,
#  '_id': ObjectId('6282945f00d4d500b4235a37'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 1, 18, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 69,
#               'datetime': datetime.datetime(2022, 1, 18, 9, 36),
#               'latitude': -36.4422,
#               'longitude': 141.4172,
#               'surface_temperature_celcius': 46},
#              {'cause': 'other',
#               'confidence': 75,
#               'datetime': datetime.datetime(2022, 1, 18, 4, 48),
#               'latitude': -36.309,
#               'longitude': 141.4964,
#               'surface_temperature_celcius': 48}],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc444b80>
# {'GHI': 126,
#  '_id': ObjectId('6282946900d4d500b4235a39'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2022, 1, 19, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 100,
#               'datetime': datetime.datetime(2022, 1, 19, 14, 24),
#               'latitude': -37.017,
#               'longitude': 148.1297,
#               'surface_temperature_celcius': 121},
#              {'cause': 'other',
#               'confidence': 77,
#               'datetime': datetime.datetime(2022, 1, 19, 4, 48),
#               'latitude': -37.586,
#               'longitude': 148.038,
#               'surface_temperature_celcius': 47},
#              {'cause': 'other',
#               'confidence': 88,
#               'datetime': datetime.datetime(2022, 1, 19, 19, 12),
#               'latitude': -37.335,
#               'longitude': 148.064,
#               'surface_temperature_celcius': 60}],
#  'max_wind_speed': 27.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 43.7,
#  'station': 948701,
#  'windspeed_knots': 17.0}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc444f00>
# {'GHI': 107,
#  '_id': ObjectId('6282947300d4d500b4235a3b'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2022, 1, 20, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 87,
#               'datetime': datetime.datetime(2022, 1, 20, 14, 24),
#               'latitude': -37.4996,
#               'longitude': 142.5966,
#               'surface_temperature_celcius': 62},
#              {'cause': 'other',
#               'confidence': 64,
#               'datetime': datetime.datetime(2022, 1, 20, 19, 12),
#               'latitude': -37.5158,
#               'longitude': 142.8257,
#               'surface_temperature_celcius': 42},
#              {'cause': 'other',
#               'confidence': 90,
#               'datetime': datetime.datetime(2022, 1, 20, 4, 48),
#               'latitude': -37.331,
#               'longitude': 143.122,
#               'surface_temperature_celcius': 65},
#              {'cause': 'other',
#               'confidence': 74,
#               'datetime': datetime.datetime(2022, 1, 20, 9, 36),
#               'latitude': -37.7545,
#               'longitude': 142.1449,
#               'surface_temperature_celcius': 48}],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.16,
#  'precipitation_flag': 'G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# <pymongo.results.InsertOneResult object at 0x7f69bc4f9580>
# {'GHI': 153,
#  '_id': ObjectId('6282947d00d4d500b4235a3d'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2022, 1, 21, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 62.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc465100>
# {'GHI': 98,
#  '_id': ObjectId('6282948700d4d500b4235a3f'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2022, 1, 22, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 97,
#               'datetime': datetime.datetime(2022, 1, 22, 19, 12),
#               'latitude': -37.0155,
#               'longitude': 148.1432,
#               'surface_temperature_celcius': 80}],
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'A',
#  'relative_humidity': 45.4,
#  'station': 948701,
#  'windspeed_knots': 5.2}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc453480>
# {'GHI': 140,
#  '_id': ObjectId('6282949100d4d500b4235a41'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 23, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 92,
#               'datetime': datetime.datetime(2022, 1, 23, 19, 12),
#               'latitude': -36.5586,
#               'longitude': 144.0423,
#               'surface_temperature_celcius': 71}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc453940>
# {'GHI': 202,
#  '_id': ObjectId('6282949b00d4d500b4235a43'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2022, 1, 24, 0, 0),
#  'hotspot': [{'cause': 'natural',
#               'confidence': 82,
#               'datetime': datetime.datetime(2022, 1, 24, 14, 24),
#               'latitude': -35.9979,
#               'longitude': 143.6803,
#               'surface_temperature_celcius': 56}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 61.0,
#  'station': 948701,
#  'windspeed_knots': 9.3}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc453b80>
# {'GHI': 138,
#  '_id': ObjectId('628294a500d4d500b4235a45'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2022, 1, 25, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 28.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 41.5,
#  'station': 948701,
#  'windspeed_knots': 17.0}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc463940>
# {'GHI': 184,
#  '_id': ObjectId('628294af00d4d500b4235a47'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2022, 1, 26, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 9.1}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc444100>
# {'GHI': 146,
#  '_id': ObjectId('628294b900d4d500b4235a49'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2022, 1, 27, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 71,
#               'datetime': datetime.datetime(2022, 1, 27, 14, 24),
#               'latitude': -37.5583,
#               'longitude': 142.9318,
#               'surface_temperature_celcius': 46},
#              {'cause': 'other',
#               'confidence': 86,
#               'datetime': datetime.datetime(2022, 1, 27, 19, 12),
#               'latitude': -37.6543,
#               'longitude': 142.91,
#               'surface_temperature_celcius': 61},
#              {'cause': 'other',
#               'confidence': 94,
#               'datetime': datetime.datetime(2022, 1, 27, 0, 0),
#               'latitude': -37.853,
#               'longitude': 142.5253,
#               'surface_temperature_celcius': 104}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc453300>
# {'GHI': 135,
#  '_id': ObjectId('628294c300d4d500b4235a4b'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2022, 1, 28, 0, 0),
#  'hotspot': [{'cause': 'other',
#               'confidence': 67,
#               'datetime': datetime.datetime(2022, 1, 28, 19, 12),
#               'latitude': -36.942,
#               'longitude': 143.292,
#               'surface_temperature_celcius': 54},
#              {'cause': 'other',
#               'confidence': 71,
#               'datetime': datetime.datetime(2022, 1, 28, 0, 0),
#               'latitude': -37.8662,
#               'longitude': 143.251,
#               'surface_temperature_celcius': 46},
#              {'cause': 'other',
#               'confidence': 92,
#               'datetime': datetime.datetime(2022, 1, 28, 4, 48),
#               'latitude': -37.4463,
#               'longitude': 142.7829,
#               'surface_temperature_celcius': 70},
#              {'cause': 'other',
#               'confidence': 68,
#               'datetime': datetime.datetime(2022, 1, 28, 4, 48),
#               'latitude': -37.9309,
#               'longitude': 143.381,
#               'surface_temperature_celcius': 44},
#              {'cause': 'other',
#               'confidence': 92,
#               'datetime': datetime.datetime(2022, 1, 28, 9, 36),
#               'latitude': -36.882,
#               'longitude': 142.7108,
#               'surface_temperature_celcius': 70}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.4}
#
# <pymongo.results.InsertOneResult object at 0x7f69bc444f00>
# {'GHI': 76,
#  '_id': ObjectId('628294cd00d4d500b4235a4d'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2022, 1, 29, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 13.0,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 36.3,
#  'station': 948701,
#  'windspeed_knots': 6.3}
