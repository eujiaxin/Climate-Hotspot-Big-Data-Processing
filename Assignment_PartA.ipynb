# %% [markdown]
# # FIT3182 Assignment Part A
#
# ### Eu Jia Xin (30881676)

# %% [markdown]
# ## Task 1. MongoDB Data Model
# Design a suitable data model to support efficient querying of the 2 datasets in MongoDB.
#
# ### 1. Example of the data model
#
#
# The following shows an **embedding** data model.
#
#
# ```json
#
# // This is an example of how the embedded data model record would look like for 7/3/2021 data.
#
#     {'GHI': 161,
#      '_id': ObjectId('627aa67f6be6617d47cf5fe8'),
#      'air_temperature_celcius': 19,
#      'date': datetime.datetime(2021, 3, 7, 0, 0),
#      'hotspot': [{'confidence': 88,
#                   'datetime': datetime.datetime(2021, 3, 7, 4, 16, 10),
#                   'latitude': -37.7752,
#                   'longitude': 141.9086,
#                   'surface_temperature_celcius': 64}],
#      'max_wind_speed': 20.0,
#      'precipitation': 0.0,
#      'precipitation_flag': 'I',
#      'relative_humidity': 51.5,
#      'station': 948701,
#      'windspeed_knots': 10.2}
# ```
#
#
# ### 2. Justification for choosing the data model
#
# Based on the two datasets, the climate data is recorded daily, whereas fire data is recorded based on the occurence of a fire on a particular day. Therefore, we can say that `climate_historic.csv` and `hotspot_historic.csv` has a one-to-many relationship.
#
# Since there is a one-to-many relationship, we can use an **embedding** data model where we will *embed* the hotspot data into the climate data. For example, for every record of the climate data, there will be zero or more hotspot data inside the 'hotspot' list within the record.
#
# The advantages of using an embedding data model is that **reading the embedded results is fast and easy**. In other words, this data model is more efficient as read operations are reduced in an embedding data model compared to a referencing model. Additionally, we will have a single collection in our database called climate, so we don't have to join between different collections.
#
# The disadvantage of using embedding data model may be that it is unsuitable if the length of hotspots for each climate is very massive and long. In our case, this is not a big problem because MongoDB document size limit (16MB) is more than enough, and can hold very large number of hotspot data. Since our data focuses on hotspots in Victoria per day, realistically there won't be that many hotspots such that MongoDB cannot accomodate.

# %% [markdown]
# ## Task 2. Querying MongoDB using PyMongo

# %% [markdown]
# ### Q2.1:
# Write a python program that will read the data from `hotspot_historic.csv` and `climate_historic.csv` and load them to the new database (e.g. fit3182_assignment_db). The collection(s) in fit3182_assignment_db will be based on the document model you have designed in Task A1.

# %%
# libraries for pymongo 
import pymongo
from pymongo import MongoClient

# libraries to process csv
import pandas as pd
import json 
from datetime import datetime 
from pprint import pprint

# file paths
CLIMATE_PATH = "datasets/climate_historic.csv"
HOTSPOT_PATH = "datasets/hotspot_historic.csv"

# date formates
DATE_FORMAT = '%Y-%m-%d'
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'

# %%
# read CSV data

climate_df = pd.read_csv(CLIMATE_PATH)
hotspot_df = pd.read_csv(HOTSPOT_PATH)

# convert datetimes
climate_df['date'] = pd.to_datetime(climate_df['date'], dayfirst=True)
hotspot_df['datetime'] = pd.to_datetime(hotspot_df['datetime'], dayfirst=True)
hotspot_df['date'] = pd.to_datetime(hotspot_df['date'], dayfirst=True)

# strip whitespaces in column names + rename to GHI for easier JSON read after
climate_df.rename(columns=lambda x: x.strip(), inplace=True)
climate_df.rename(columns={"GHI_w/m2":"GHI"}, inplace=True)

# # pre-process precipitation into value and flag (2 separate columns)
result = climate_df['precipitation'].str.split('(\d.[\d+]*)([A-I])', expand=True)
result = result.loc[:,[1,2]]
result.rename(columns={1:'precipitation', 2:'precipitation_flag'}, inplace=True)


# update climate dataframe with pre-processed precipitation columns
climate_df['precipitation'] = pd.to_numeric(result['precipitation'])
climate_df.insert(loc=7, column='precipitation_flag', value=result['precipitation_flag'].astype(str))

# prior to json conversion, format date properly
climate_df['date'] = climate_df['date'].dt.strftime(DATE_FORMAT)
hotspot_df['date'] = hotspot_df['date'].dt.strftime(DATE_FORMAT)
hotspot_df['datetime'] = hotspot_df['datetime'].dt.strftime(DATETIME_FORMAT)

climate_df.head()
# Out:
#    station        date  air_temperature_celcius  relative_humidity  \
# 0   948700  2020-12-31                       19               56.8
# 1   948700  2021-01-02                       15               50.7
# 2   948700  2021-01-03                       16               53.6
# 3   948700  2021-01-04                       24               61.6
# 4   948700  2021-01-05                       24               62.3
#
#    windspeed_knots  max_wind_speed  precipitation precipitation_flag  GHI
# 0              7.9            11.1           0.00                  I  154
# 1              9.2            13.0           0.02                  G  128
# 2              8.1            15.0           0.00                  G  133
# 3              7.7            14.0           0.00                  I  186
# 4              7.0            13.0           0.00                  I  185

# %%
# convert climate data to a list of JSON objects
result = climate_df.to_json(orient="records")
document = json.loads(result)

# for every climate data, we will find the corresponding hotspot data (>=0)
for row in document:
    hotspots = hotspot_df.loc[hotspot_df['date'] == row['date']]
    # use a single 'datetime' field (encompasses the 'date' data already)
    hotspots = hotspots[['datetime', 'latitude', 'longitude', 'confidence', 'surface_temperature_celcius']]
    
    # add the embedding hotspot data into climate data
    hotspot_embed = hotspots.to_json(orient='records')
    hotspot_embed = json.loads(hotspot_embed)
    row['hotspot'] = hotspot_embed
    
    # processed current climate data, update to correct date format before inserting into db
    row['date'] = datetime.strptime(row['date'], DATE_FORMAT)
    for hotspot in row['hotspot']:
        hotspot['datetime'] = datetime.strptime(hotspot['datetime'], '%Y-%m-%dT%H:%M:%S')
    

document = sorted(document, key=lambda d: d['date'])

# %%
# connect to MongoClient on default host and port
client = MongoClient() 

# get database
db = client.fit3182_assignment_db

# get climate collection (drop any existing collection to re-populate)
collection = db.climate
collection.drop()

# inserting the embedding document into our db collection
result = collection.insert_many(document)

# %% [markdown]
# ### Q2.2:
# Write queries to answer the following tasks on `fit3182_assignment_db`.

# %%
def print_cursor(cursor):
    """
    Format printing of multiple records within cursor object
    """
    for record in cursor:
        pprint(record)

# %%
# 2.2a) Find climate data on 12th December 2021.

# use data query to find exact data
date_query = datetime(2021, 12, 12)
climate_data = collection.find_one({'date': date_query})

pprint(climate_data)
# Out:
# {'GHI': 156,
#  '_id': ObjectId('628292f65b3178ab2dcced55'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 12, 12, 0, 0),
#  'hotspot': [{'confidence': 53,
#               'datetime': datetime.datetime(2021, 12, 12, 0, 45, 38),
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %%
# 2.2b) Find the latitude, longitude, surface temperature (°C), and confidence
# when the surface temperature (°C) was between 65 °C and 100 °C.

pipeline = [
    # flatten the hotspots 
    {'$unwind': '$hotspot'},
    # filter by matching valid temperature
    {'$match': {'hotspot.surface_temperature_celcius': {"$gte": 65, "$lte": 100}} },
    # project only needed fields
    {"$project": {'_id':False, 'hotspot.latitude':True, 'hotspot.longitude':True, 
                  'hotspot.surface_temperature_celcius':True, 'hotspot.confidence':True}}
     
]

hotspots = collection.aggregate(pipeline=pipeline)

print_cursor(hotspots)
# Out:
# {'hotspot': {'confidence': 94,
#              'latitude': -37.2284,
#              'longitude': 147.9187,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.6572,
#              'longitude': 142.0703,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 84,
#              'latitude': -37.0193,
#              'longitude': 148.1459,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.4229,
#              'longitude': 147.027,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 80,
#              'latitude': -37.0055,
#              'longitude': 148.1582,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 85,
#              'latitude': -37.4128,
#              'longitude': 147.0242,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 90,
#              'latitude': -34.357,
#              'longitude': 141.5361,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 93,
#              'latitude': -34.3539,
#              'longitude': 141.5547,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.9939,
#              'longitude': 148.2244,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.9959,
#              'longitude': 148.2118,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 89,
#              'latitude': -34.3654,
#              'longitude': 141.543,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 96,
#              'latitude': -34.3554,
#              'longitude': 141.5413,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 94,
#              'latitude': -34.3555,
#              'longitude': 141.5495,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.7152,
#              'longitude': 141.3853,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.0155,
#              'longitude': 148.1432,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.6622,
#              'longitude': 142.1001,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.4523,
#              'longitude': 147.0175,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.4261,
#              'longitude': 147.0323,
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.3949,
#              'longitude': 147.0175,
#              'surface_temperature_celcius': 91}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.6625,
#              'longitude': 144.287,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 82,
#              'latitude': -37.8973,
#              'longitude': 143.4754,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.7805,
#              'longitude': 143.5003,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.8774,
#              'longitude': 145.8213,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.8881,
#              'longitude': 145.8229,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 71,
#              'latitude': -37.522,
#              'longitude': 143.3874,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 91,
#              'latitude': -38.0674,
#              'longitude': 142.965,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 92,
#              'latitude': -38.0715,
#              'longitude': 142.9591,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.0693,
#              'longitude': 142.9722,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.4557,
#              'longitude': 142.2434,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.8009,
#              'longitude': 142.7259,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.8099,
#              'longitude': 142.728,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.7806,
#              'longitude': 141.5597,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 98,
#              'latitude': -34.3526,
#              'longitude': 141.6458,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.0924,
#              'longitude': 141.897,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.9452,
#              'longitude': 143.5834,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 99,
#              'latitude': -34.351,
#              'longitude': 141.6567,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5012,
#              'longitude': 142.5853,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.9247,
#              'longitude': 142.8999,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 97,
#              'latitude': -35.0805,
#              'longitude': 142.4642,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.3735,
#              'longitude': 145.886,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.7465,
#              'longitude': 143.3806,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.8072,
#              'longitude': 145.9738,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.3704,
#              'longitude': 145.8942,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.297,
#              'longitude': 143.5753,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.2988,
#              'longitude': 143.5487,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.3025,
#              'longitude': 143.5714,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.383,
#              'longitude': 145.9089,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.7446,
#              'longitude': 143.4085,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.7509,
#              'longitude': 143.4023,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.7974,
#              'longitude': 145.9535,
#              'surface_temperature_celcius': 97}}
# {'hotspot': {'confidence': 90,
#              'latitude': -35.7657,
#              'longitude': 142.0906,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.7236,
#              'longitude': 143.3995,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.3046,
#              'longitude': 143.5448,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.4312,
#              'longitude': 141.2064,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.1556,
#              'longitude': 141.5904,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 89,
#              'latitude': -35.7647,
#              'longitude': 142.0858,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 90,
#              'latitude': -35.4033,
#              'longitude': 143.267,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 64,
#              'latitude': -36.6281,
#              'longitude': 142.4349,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 85,
#              'latitude': -36.111,
#              'longitude': 145.124,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.1615,
#              'longitude': 141.8728,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.1122,
#              'longitude': 142.1491,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.3735,
#              'longitude': 145.8384,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 89,
#              'latitude': -35.4255,
#              'longitude': 143.6306,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.1955,
#              'longitude': 145.914,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 85,
#              'latitude': -35.4533,
#              'longitude': 143.2029,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.5989,
#              'longitude': 141.9771,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 66,
#              'latitude': -36.6299,
#              'longitude': 142.4234,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.1925,
#              'longitude': 145.93,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 98,
#              'latitude': -36.095,
#              'longitude': 141.7699,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.6006,
#              'longitude': 141.9657,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.0769,
#              'longitude': 141.042,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 79,
#              'latitude': -36.883,
#              'longitude': 142.1637,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 87,
#              'latitude': -36.0973,
#              'longitude': 143.4279,
#              'surface_temperature_celcius': 92}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.1819,
#              'longitude': 145.9269,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.6387,
#              'longitude': 142.9032,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.6439,
#              'longitude': 142.913,
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.3165,
#              'longitude': 147.4932,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.3158,
#              'longitude': 147.4986,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.4471,
#              'longitude': 147.6331,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.7835,
#              'longitude': 148.4138,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.4449,
#              'longitude': 147.6594,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.4323,
#              'longitude': 147.6583,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.4343,
#              'longitude': 147.6327,
#              'surface_temperature_celcius': 92}}
# {'hotspot': {'confidence': 84,
#              'latitude': -37.5816,
#              'longitude': 148.5862,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.6334,
#              'longitude': 142.2244,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 76,
#              'latitude': -37.7966,
#              'longitude': 142.3196,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.805,
#              'longitude': 142.1326,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.8429,
#              'longitude': 143.8366,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 77,
#              'latitude': -37.8062,
#              'longitude': 143.3598,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.9918,
#              'longitude': 141.8667,
#              'surface_temperature_celcius': 97}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.1104,
#              'longitude': 145.9829,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.782,
#              'longitude': 148.3844,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.9902,
#              'longitude': 141.879,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.745,
#              'longitude': 142.993,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.0157,
#              'longitude': 145.9414,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.777,
#              'longitude': 148.4128,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.5888,
#              'longitude': 148.5949,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 89,
#              'latitude': -34.3943,
#              'longitude': 141.7567,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 81,
#              'latitude': -36.0844,
#              'longitude': 141.4934,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.031,
#              'longitude': 145.6824,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 86,
#              'latitude': -37.5814,
#              'longitude': 148.5777,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.5788,
#              'longitude': 148.592,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.6384,
#              'longitude': 142.4075,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 94,
#              'latitude': -35.811,
#              'longitude': 142.1403,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.9034,
#              'longitude': 141.0013,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 88,
#              'latitude': -37.7746,
#              'longitude': 148.3673,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 83,
#              'latitude': -37.803,
#              'longitude': 142.3151,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.7542,
#              'longitude': 142.9949,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.3803,
#              'longitude': 145.611,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.7617,
#              'longitude': 143.081,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.8161,
#              'longitude': 142.9286,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.0387,
#              'longitude': 145.6787,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.6349,
#              'longitude': 142.2125,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.9018,
#              'longitude': 141.0146,
#              'surface_temperature_celcius': 100}}
# {'hotspot': {'confidence': 86,
#              'latitude': -36.6986,
#              'longitude': 142.7259,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 94,
#              'latitude': -38.0052,
#              'longitude': 142.6179,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.2168,
#              'longitude': 147.4748,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.222,
#              'longitude': 147.4689,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.2063,
#              'longitude': 147.4713,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.2082,
#              'longitude': 147.4368,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.224,
#              'longitude': 147.4347,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 67,
#              'latitude': -37.34,
#              'longitude': 149.3668,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 99,
#              'latitude': -36.7287,
#              'longitude': 142.6017,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 91,
#              'latitude': -35.2363,
#              'longitude': 143.0004,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.2378,
#              'longitude': 142.9864,
#              'surface_temperature_celcius': 94}}
# {'hotspot': {'confidence': 98,
#              'latitude': -35.2381,
#              'longitude': 142.994,
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 66,
#              'latitude': -37.3493,
#              'longitude': 149.3691,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.7165,
#              'longitude': 142.6155,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 94,
#              'latitude': -37.5812,
#              'longitude': 142.7374,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5949,
#              'longitude': 142.6857,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.8247,
#              'longitude': 143.6243,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.4028,
#              'longitude': 143.6932,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.4033,
#              'longitude': 143.6884,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.8249,
#              'longitude': 143.6174,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.6823,
#              'longitude': 142.5024,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.4489,
#              'longitude': 144.7685,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.9498,
#              'longitude': 142.2012,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.1941,
#              'longitude': 143.1604,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.4142,
#              'longitude': 143.1077,
#              'surface_temperature_celcius': 97}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.1924,
#              'longitude': 143.1716,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.0295,
#              'longitude': 143.6409,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.0761,
#              'longitude': 141.0574,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 93,
#              'latitude': -35.0616,
#              'longitude': 141.4417,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.3999,
#              'longitude': 144.737,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.1748,
#              'longitude': 145.7582,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 99,
#              'latitude': -36.0691,
#              'longitude': 145.7797,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 90,
#              'latitude': -35.1949,
#              'longitude': 141.0622,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.91,
#              'longitude': 141.2705,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 89,
#              'latitude': -35.8071,
#              'longitude': 142.7318,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.7787,
#              'longitude': 141.4449,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 98,
#              'latitude': -36.2948,
#              'longitude': 141.3486,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 89,
#              'latitude': -38.1561,
#              'longitude': 143.7846,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.8185,
#              'longitude': 142.5609,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.1771,
#              'longitude': 145.7451,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.027,
#              'longitude': 142.3844,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 89,
#              'latitude': -35.7642,
#              'longitude': 143.3321,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.429,
#              'longitude': 141.5759,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.1346,
#              'longitude': 145.2196,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.0899,
#              'longitude': 141.0238,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.3823,
#              'longitude': 141.3146,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.1462,
#              'longitude': 145.2096,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.5243,
#              'longitude': 142.0839,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.618,
#              'longitude': 143.0013,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.8867,
#              'longitude': 142.1873,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.9364,
#              'longitude': 143.4996,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.3847,
#              'longitude': 142.8935,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.6374,
#              'longitude': 142.3787,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.8835,
#              'longitude': 142.2098,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.4125,
#              'longitude': 143.1189,
#              'surface_temperature_celcius': 92}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.0669,
#              'longitude': 141.0556,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.0714,
#              'longitude': 145.7665,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.2933,
#              'longitude': 141.36,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.4591,
#              'longitude': 144.9492,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.3487,
#              'longitude': 145.5315,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.5399,
#              'longitude': 144.678,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.8158,
#              'longitude': 142.6229,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.4518,
#              'longitude': 144.7752,
#              'surface_temperature_celcius': 97}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.7903,
#              'longitude': 141.618,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.1067,
#              'longitude': 143.7948,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.1441,
#              'longitude': 145.2221,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.4816,
#              'longitude': 141.6635,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.0837,
#              'longitude': 144.2448,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.782,
#              'longitude': 141.8851,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.5586,
#              'longitude': 144.0423,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.5568,
#              'longitude': 144.0538,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.4538,
#              'longitude': 144.763,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.4612,
#              'longitude': 144.7775,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.7089,
#              'longitude': 143.3518,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.601,
#              'longitude': 144.6378,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.8681,
#              'longitude': 143.5186,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.1999,
#              'longitude': 143.8231,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.6171,
#              'longitude': 142.9426,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 84,
#              'latitude': -37.7587,
#              'longitude': 142.8521,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.4611,
#              'longitude': 144.9371,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.0254,
#              'longitude': 142.3959,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.88,
#              'longitude': 143.7233,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.8885,
#              'longitude': 143.9157,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 95,
#              'latitude': -35.0706,
#              'longitude': 141.4435,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.0795,
#              'longitude': 143.2449,
#              'surface_temperature_celcius': 91}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.1857,
#              'longitude': 141.0604,
#              'surface_temperature_celcius': 92}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.6469,
#              'longitude': 142.376,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 91,
#              'latitude': -35.6453,
#              'longitude': 142.387,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.4409,
#              'longitude': 141.6948,
#              'surface_temperature_celcius': 92}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.9174,
#              'longitude': 145.8678,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.9152,
#              'longitude': 145.8808,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.8906,
#              'longitude': 146.2035,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.8182,
#              'longitude': 143.8739,
#              'surface_temperature_celcius': 92}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.9246,
#              'longitude': 146.2464,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.3313,
#              'longitude': 141.0017,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.2857,
#              'longitude': 141.3467,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.0749,
#              'longitude': 143.4058,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.4449,
#              'longitude': 140.9836,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.3972,
#              'longitude': 141.6041,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.5532,
#              'longitude': 142.5349,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.1367,
#              'longitude': 145.2071,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.1518,
#              'longitude': 144.0233,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.1418,
#              'longitude': 144.0261,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 75,
#              'latitude': -36.7499,
#              'longitude': 141.3006,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 84,
#              'latitude': -36.7432,
#              'longitude': 141.3296,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 84,
#              'latitude': -36.7531,
#              'longitude': 141.3253,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 99,
#              'latitude': -36.7943,
#              'longitude': 143.9571,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.7957,
#              'longitude': 143.9652,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 98,
#              'latitude': -36.9329,
#              'longitude': 143.7796,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 99,
#              'latitude': -35.8276,
#              'longitude': 143.7549,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 78,
#              'latitude': -35.9326,
#              'longitude': 141.958,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.6892,
#              'longitude': 145.2775,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.73,
#              'longitude': 143.935,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.8283,
#              'longitude': 143.4605,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.6527,
#              'longitude': 142.7392,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.1898,
#              'longitude': 145.0922,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.8298,
#              'longitude': 143.4483,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.6615,
#              'longitude': 144.6014,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.8238,
#              'longitude': 143.5724,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.1988,
#              'longitude': 145.0941,
#              'surface_temperature_celcius': 100}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.7651,
#              'longitude': 143.5801,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.5199,
#              'longitude': 144.7311,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.0782,
#              'longitude': 145.3625,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.3966,
#              'longitude': 141.406,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.1349,
#              'longitude': 141.9491,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.6397,
#              'longitude': 142.5968,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.6267,
#              'longitude': 142.9993,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.5871,
#              'longitude': 144.4958,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.2618,
#              'longitude': 141.8783,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.6828,
#              'longitude': 144.784,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.4843,
#              'longitude': 143.0592,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 94,
#              'latitude': -37.7274,
#              'longitude': 142.9536,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.6964,
#              'longitude': 142.8583,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 98,
#              'latitude': -38.0509,
#              'longitude': 143.9423,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.9284,
#              'longitude': 143.108,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5701,
#              'longitude': 142.6497,
#              'surface_temperature_celcius': 94}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.7101,
#              'longitude': 142.3865,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 93,
#              'latitude': -38.1693,
#              'longitude': 143.0466,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.7128,
#              'longitude': 142.3717,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.4885,
#              'longitude': 142.0658,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 77,
#              'latitude': -36.7101,
#              'longitude': 142.981,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.0959,
#              'longitude': 143.8206,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.9594,
#              'longitude': 143.5638,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 98,
#              'latitude': -36.5921,
#              'longitude': 144.4905,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.6787,
#              'longitude': 144.8042,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 84,
#              'latitude': -38.0423,
#              'longitude': 146.4048,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 94,
#              'latitude': -38.1224,
#              'longitude': 143.7553,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 94,
#              'latitude': -38.0792,
#              'longitude': 143.7361,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.9157,
#              'longitude': 143.3544,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.7935,
#              'longitude': 143.1606,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.7756,
#              'longitude': 143.1388,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.7171,
#              'longitude': 142.9505,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 94,
#              'latitude': -37.7236,
#              'longitude': 142.947,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.7002,
#              'longitude': 142.9562,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.6498,
#              'longitude': 142.5997,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5728,
#              'longitude': 142.6348,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.4352,
#              'longitude': 143.1444,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.5828,
#              'longitude': 144.5775,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.5987,
#              'longitude': 144.4995,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 98,
#              'latitude': -36.5262,
#              'longitude': 144.5737,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.6995,
#              'longitude': 142.978,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.8879,
#              'longitude': 141.6647,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 100,
#              'latitude': -35.8768,
#              'longitude': 145.4627,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.4899,
#              'longitude': 142.2805,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.663,
#              'longitude': 141.3038,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.092,
#              'longitude': 141.7306,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 89,
#              'latitude': -34.9023,
#              'longitude': 142.0557,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.2637,
#              'longitude': 145.3649,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.2609,
#              'longitude': 141.7999,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.91,
#              'longitude': 141.0704,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.2652,
#              'longitude': 145.3769,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.738,
#              'longitude': 142.1177,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 89,
#              'latitude': -37.876,
#              'longitude': 143.7804,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 88,
#              'latitude': -36.1546,
#              'longitude': 141.8146,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.9091,
#              'longitude': 143.5105,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 80,
#              'latitude': -36.1559,
#              'longitude': 141.8102,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.9071,
#              'longitude': 143.538,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.3902,
#              'longitude': 148.2955,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5027,
#              'longitude': 146.347,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5043,
#              'longitude': 146.3299,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.1964,
#              'longitude': 144.5217,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.769,
#              'longitude': 147.94,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.1303,
#              'longitude': 146.3606,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 98,
#              'latitude': -36.1345,
#              'longitude': 146.351,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 99,
#              'latitude': -36.1586,
#              'longitude': 145.6666,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.5847,
#              'longitude': 145.1968,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.9111,
#              'longitude': 142.692,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.5115,
#              'longitude': 143.14,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 86,
#              'latitude': -37.6775,
#              'longitude': 148.5131,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 87,
#              'latitude': -36.3332,
#              'longitude': 145.8594,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 70,
#              'latitude': -36.9303,
#              'longitude': 143.1034,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 83,
#              'latitude': -36.3195,
#              'longitude': 146.0601,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.5839,
#              'longitude': 143.0588,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.5854,
#              'longitude': 143.0462,
#              'surface_temperature_celcius': 94}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.3014,
#              'longitude': 143.203,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.1917,
#              'longitude': 147.0745,
#              'surface_temperature_celcius': 94}}
# {'hotspot': {'confidence': 95,
#              'latitude': -38.1987,
#              'longitude': 147.0666,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.5454,
#              'longitude': 144.7402,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.7593,
#              'longitude': 142.895,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.3435,
#              'longitude': 141.5513,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.6942,
#              'longitude': 143.8021,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.3459,
#              'longitude': 141.5586,
#              'surface_temperature_celcius': 91}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.4046,
#              'longitude': 141.1534,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.0594,
#              'longitude': 141.5907,
# ...
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 98,
#              'latitude': -38.2375,
#              'longitude': 142.8363,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.4463,
#              'longitude': 142.7829,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.6854,
#              'longitude': 143.4543,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 99,
#              'latitude': -38.0881,
#              'longitude': 143.9391,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 96,
#              'latitude': -38.0866,
#              'longitude': 143.9534,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 92,
#              'latitude': -38.2391,
#              'longitude': 142.82,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.5123,
#              'longitude': 146.4007,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.3438,
#              'longitude': 141.5832,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 94,
#              'latitude': -37.4357,
#              'longitude': 142.7813,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.5867,
#              'longitude': 143.6256,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.2911,
#              'longitude': 141.1664,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.2842,
#              'longitude': 141.1741,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.7218,
#              'longitude': 141.6411,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 84,
#              'latitude': -37.3656,
#              'longitude': 141.3903,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.4179,
#              'longitude': 144.2924,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.3207,
#              'longitude': 140.9737,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 99,
#              'latitude': -36.2882,
#              'longitude': 141.1821,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.3153,
#              'longitude': 140.9789,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.4169,
#              'longitude': 144.2994,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.4671,
#              'longitude': 145.9962,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.3254,
#              'longitude': 144.3638,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.0816,
#              'longitude': 145.859,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.1532,
#              'longitude': 143.5527,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.0077,
#              'longitude': 141.7747,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.0828,
#              'longitude': 145.873,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.5541,
#              'longitude': 144.1321,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 91,
#              'latitude': -35.6819,
#              'longitude': 143.5275,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 90,
#              'latitude': -35.6871,
#              'longitude': 143.5235,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.1506,
#              'longitude': 143.5671,
#              'surface_temperature_celcius': 95}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.4984,
#              'longitude': 142.9739,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.253,
#              'longitude': 144.3681,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.9396,
#              'longitude': 143.1462,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.3387,
#              'longitude': 141.7542,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.3433,
#              'longitude': 143.4369,
#              'surface_temperature_celcius': 94}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.345,
#              'longitude': 143.4256,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.7032,
#              'longitude': 144.0992,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.3402,
#              'longitude': 141.7429,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.5661,
#              'longitude': 142.2956,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 85,
#              'latitude': -36.5023,
#              'longitude': 143.6038,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.8616,
#              'longitude': 142.8025,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 90,
#              'latitude': -38.0372,
#              'longitude': 146.0616,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 94,
#              'latitude': -38.049,
#              'longitude': 146.0513,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 89,
#              'latitude': -35.4666,
#              'longitude': 142.0749,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.0396,
#              'longitude': 141.7183,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.2775,
#              'longitude': 146.1026,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.0361,
#              'longitude': 146.0567,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.7746,
#              'longitude': 146.6642,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.8359,
#              'longitude': 146.6448,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.9085,
#              'longitude': 141.1038,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.4349,
#              'longitude': 146.3122,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 89,
#              'latitude': -38.4792,
#              'longitude': 146.3081,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.9047,
#              'longitude': 141.0945,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.7685,
#              'longitude': 142.7134,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.7801,
#              'longitude': 142.7151,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 96,
#              'latitude': -36.1002,
#              'longitude': 142.3405,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.4325,
#              'longitude': 144.3142,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.2693,
#              'longitude': 143.1768,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 91,
#              'latitude': -36.3774,
#              'longitude': 143.7079,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.3756,
#              'longitude': 143.7243,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 97,
#              'latitude': -36.369,
#              'longitude': 143.7132,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.3799,
#              'longitude': 143.7149,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.8644,
#              'longitude': 143.4263,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 89,
#              'latitude': -38.3998,
#              'longitude': 147.064,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 94,
#              'latitude': -37.4796,
#              'longitude': 141.9403,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 58,
#              'latitude': -37.379,
#              'longitude': 148.126,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 62,
#              'latitude': -37.379,
#              'longitude': 148.132,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.396,
#              'longitude': 148.086,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.399,
#              'longitude': 148.081,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.401,
#              'longitude': 148.067,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.446,
#              'longitude': 148.102,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.406,
#              'longitude': 148.123,
#              'surface_temperature_celcius': 88}}
# {'hotspot': {'confidence': 68,
#              'latitude': -37.452,
#              'longitude': 148.115,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 64,
#              'latitude': -37.45,
#              'longitude': 148.126,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 86,
#              'latitude': -37.436,
#              'longitude': 148.088,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 73,
#              'latitude': -37.444,
#              'longitude': 148.101,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 61,
#              'latitude': -37.562,
#              'longitude': 148.05,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.462,
#              'longitude': 148.089,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 88,
#              'latitude': -37.46,
#              'longitude': 148.102,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 96,
#              'latitude': -38.127,
#              'longitude': 143.82,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.294,
#              'longitude': 141.232,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.293,
#              'longitude': 141.245,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.247,
#              'longitude': 141.278,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.098,
#              'longitude': 143.74,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.331,
#              'longitude': 143.122,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.477,
#              'longitude': 143.352,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.475,
#              'longitude': 143.365,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.69,
#              'longitude': 143.605,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.94,
#              'longitude': 143.281,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.862,
#              'longitude': 144.175,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.945,
#              'longitude': 144.354,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.606,
#              'longitude': 149.312,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.61,
#              'longitude': 149.307,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.609,
#              'longitude': 149.32,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.642,
#              'longitude': 149.263,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.634,
#              'longitude': 149.237,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.605,
#              'longitude': 149.302,
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.6,
#              'longitude': 149.325,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.618,
#              'longitude': 149.281,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.282,
#              'longitude': 146.157,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.95,
#              'longitude': 142.366,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.875,
#              'longitude': 142.51,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.613,
#              'longitude': 149.305,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.624,
#              'longitude': 149.314,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 93,
#              'latitude': -38.057,
#              'longitude': 144.211,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 78,
#              'latitude': -37.966,
#              'longitude': 145.051,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 86,
#              'latitude': -35.543,
#              'longitude': 143.316,
#              'surface_temperature_celcius': 67}}

# %%
# 2.2c) Find date, surface temperature (°C), air temperature (°C), 
# relative humidity and max wind speed on 15th and 16th of December 2021.

date1 = datetime(2021, 12, 15)
date2 = datetime(2021, 12, 16)

pipeline = [
    {'$match': {'$or': [{"date":date1}, {"date":date2}] } },
    {'$project': {'_id':False, 
                  'date':True,
                  'hotspot.surface_temperature_celcius':True, 
                  'air_temperature_celcius':True, 
                  'relative_humidity': True, 
                  'max_wind_speed':True, }}
] 
result = collection.aggregate(pipeline=pipeline)

print_cursor(result)
# Out:
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'hotspot': [{'surface_temperature_celcius': 42},
#              {'surface_temperature_celcius': 36},
#              {'surface_temperature_celcius': 38},
#              {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'hotspot': [{'surface_temperature_celcius': 43},
#              {'surface_temperature_celcius': 33},
#              {'surface_temperature_celcius': 54},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 75},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 66},
#              {'surface_temperature_celcius': 56},
#              {'surface_temperature_celcius': 60},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 48},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 64},
#              {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %%
# 2.2d) Find datetime, air temperature (°C), surface temperature (°C) and confidence
# when the confidence is between 80 and 100

pipeline = [
    # flatten hotspots
    {'$unwind': '$hotspot'},
    # filter for hotspots with valid confidence level
    {'$match': {'hotspot.confidence': {"$gte": 80, "$lte": 100}} },
    # project needed fields
    {'$project': {'_id':False, 
#                   "hotspot.datetime":{ "$dateToString":{"format":DATETIME_FORMAT, "date":"$hotspot.datetime"}},
                  'hotspot.datetime':True,
                  'air_temperature_celcius':True, 
                  'hotspot.surface_temperature_celcius':True, 'hotspot.confidence':True }},
] 
result = collection.aggregate(pipeline=pipeline)

print_cursor(result)
# Out:
# {'air_temperature_celcius': 20,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 6, 5, 6, 30),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 20,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 3, 6, 5, 6, 20),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 3, 7, 4, 16, 10),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 3, 9, 13, 23, 40),
#              'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 48, 40),
#              'surface_temperature_celcius': 105}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 46, 20),
#              'surface_temperature_celcius': 109}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 45, 30),
#              'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 45, 30),
#              'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 43, 50),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 3, 12, 4, 33, 50),
#              'surface_temperature_celcius': 105}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 3, 12, 4, 29, 50),
#              'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 12, 4, 28, 20),
#              'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 3, 12, 4, 28),
#              'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 3, 12, 4, 27, 20),
#              'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 24, 40),
#              'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 22, 20),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 20, 50),
#              'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 16, 30),
#              'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 16, 20),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 14, 40),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 14, 30),
#              'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 3, 14, 4, 14, 30),
#              'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 3, 17, 4, 48, 20),
#              'surface_temperature_celcius': 74}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 3, 17, 4, 45, 10),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 3, 17, 4, 45),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 18, 3, 50, 50),
#              'surface_temperature_celcius': 121}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 3, 18, 3, 50, 40),
#              'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 39, 50),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#              'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 36),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 98,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 33),
#              'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#              'surface_temperature_celcius': 91}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#              'surface_temperature_celcius': 113}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#              'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#              'surface_temperature_celcius': 106}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 59, 50),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 58, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 58, 10),
#              'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#              'surface_temperature_celcius': 111}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#              'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 56, 40),
#              'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 43, 20),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 40, 50),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 50),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 91,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 38),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 33, 40),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 33, 30),
#              'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 33, 30),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 32, 20),
#              'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 30, 50),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 30, 20),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#              'surface_temperature_celcius': 74}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 98,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#              'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#              'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 27, 40),
#              'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 27, 20),
#              'surface_temperature_celcius': 107}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 27, 10),
#              'surface_temperature_celcius': 108}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 27),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 99,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 27),
#              'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 3, 31, 5, 7, 10),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 3, 31, 5, 1, 20),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 58, 30),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 58),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 3, 31, 0, 36, 30),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 91,
#              'datetime': datetime.datetime(2021, 4, 3, 13, 17),
#              'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 3, 13, 15, 30),
#              'surface_temperature_celcius': 40}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 13, 15, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 4, 3, 13, 15, 10),
#              'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 59, 10),
#              'surface_temperature_celcius': 96}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 57, 50),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 56, 20),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 55, 10),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 55, 10),
#              'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 54),
#              'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 53, 50),
#              'surface_temperature_celcius': 93}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 53, 30),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 30),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 30),
#              'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 20),
#              'surface_temperature_celcius': 115}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 10),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 10),
#              'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 10),
#              'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 10),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51, 30),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51, 30),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 98,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51),
#              'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51),
#              'surface_temperature_celcius': 103}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#              'surface_temperature_celcius': 97}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 99,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 3, 1, 7, 20),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 4, 15, 31),
#              'surface_temperature_celcius': 44}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 15, 30, 40),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 41, 50),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 41, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 41),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 41),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 40),
#              'surface_temperature_celcius': 120}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 50),
#              'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 50),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 40),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 40),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 20),
#              'surface_temperature_celcius': 107}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 37, 10),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 36, 10),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 36, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 36),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 35),
#              'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34, 50),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34, 20),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34, 20),
#              'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34, 20),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 50),
#              'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 40),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 30),
#              'surface_temperature_celcius': 113}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 30),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 30),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 10),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33),
#              'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 98,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 123}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'surface_temperature_celcius': 118}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 120}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 92}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 101}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 4, 0, 12, 50),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 9),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 9),
#              'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 8, 40),
#              'surface_temperature_celcius': 44}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 8, 40),
#              'surface_temperature_celcius': 47}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 7),
#              'surface_temperature_celcius': 40}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 4, 20),
#              'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 3, 20),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 98,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 3),
#              'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 3),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 3),
#              'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 2, 40),
#              'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 2, 40),
#              'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 5, 5, 16, 50),
#              'surface_temperature_celcius': 88}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 5, 5, 15, 30),
#              'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 40, 50),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 40, 30),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 40, 20),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 30),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 30),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 20),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 20),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'surface_temperature_celcius': 92}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 4, 6, 13, 45, 30),
#              'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 32, 20),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 31, 10),
#              'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27, 50),
#              'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27, 50),
#              'surface_temperature_celcius': 88}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27, 10),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27),
#              'surface_temperature_celcius': 97}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27),
#              'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 27),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 24, 40),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 24, 20),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 24, 20),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 24),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 50),
#              'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 99,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 50),
#              'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 30),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 10),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 40),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 20),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 20),
#              'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 20),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 20),
#              'surface_temperature_celcius': 103}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 91,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 20),
#              'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 10),
#              'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 10),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 10),
#              'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21, 30),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21, 10),
#              'surface_temperature_celcius': 96}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21),
#              'surface_temperature_celcius': 115}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 50),
#              'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 50),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 50),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 91,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 104}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 100}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 56, 50),
#              'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 56, 30),
#              'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 56, 30),
#              'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 53, 40),
#              'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 52, 10),
#              'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 51, 20),
#              'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 51),
#              'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 50, 50),
#              'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 50, 40),
#              'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 4, 7, 5, 9, 50),
#              'surface_temperature_celcius': 54}}
# ...
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#              'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 10, 4, 4, 41, 2),
#              'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#              'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 91,
#              'datetime': datetime.datetime(2021, 10, 7, 12, 59, 33),
#              'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 10, 10, 4, 4, 19),
#              'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 10, 15, 4, 23, 1),
#              'surface_temperature_celcius': 87}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 99,
#              'datetime': datetime.datetime(2021, 10, 15, 4, 23, 1),
#              'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 10, 17, 13, 36, 12),
#              'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 91,
#              'datetime': datetime.datetime(2021, 10, 17, 4, 10, 45),
#              'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 10, 17, 4, 10, 32),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 10, 18, 0, 39, 2),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 10, 18, 0, 39, 2),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 10, 20, 4, 41, 19),
#              'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 10, 20, 4, 41, 19),
#              'surface_temperature_celcius': 50}}
# {'air_temperature_celcius': 12,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 10, 21, 1, 9, 55),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 12,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 10, 21, 1, 9, 54),
#              'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 10, 26, 13, 30, 31),
#              'surface_temperature_celcius': 48}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 10, 26, 13, 30, 31),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 10, 27, 4, 47, 31),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 10, 28, 3, 52, 17),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 11, 5, 4, 41, 34),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 11, 5, 4, 41, 19),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 11, 5, 4, 41, 19),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#              'surface_temperature_celcius': 93}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 96,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#              'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 44),
#              'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 44),
#              'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 11, 11, 13, 30, 8),
#              'surface_temperature_celcius': 37}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 11, 13, 30, 8),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 11, 11, 4, 4, 25),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 89,
#              'datetime': datetime.datetime(2021, 11, 12, 0, 33, 15),
#              'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 11, 13, 3, 52, 15),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 11, 13, 3, 52, 14),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 11, 14, 4, 35, 4),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 85,
#              'datetime': datetime.datetime(2021, 11, 21, 0, 27, 21),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 11, 22, 3, 46),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 88,
#              'datetime': datetime.datetime(2021, 11, 22, 3, 46),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 11, 23, 4, 28, 59),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 11, 23, 4, 28, 59),
#              'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#              'surface_temperature_celcius': 87}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 97,
#              'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#              'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 99,
#              'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#              'surface_temperature_celcius': 84}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#              'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#              'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#              'surface_temperature_celcius': 38}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#              'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#              'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 14),
#              'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#              'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 98,
#              'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#              'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#              'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 99,
#              'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#              'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#              'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#              'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 12, 8, 13, 11, 44),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 12, 8, 13, 11, 44),
#              'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 12, 8, 13, 11, 43),
#              'surface_temperature_celcius': 52}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 87,
#              'datetime': datetime.datetime(2021, 12, 9, 0, 14, 34),
#              'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': datetime.datetime(2021, 12, 9, 0, 14, 34),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 12, 9, 0, 14, 33),
#              'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 12, 9, 0, 14, 33),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 83,
#              'datetime': datetime.datetime(2021, 12, 13, 4, 4, 19),
#              'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 12, 14, 4, 47, 25),
#              'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 92,
#              'datetime': datetime.datetime(2021, 12, 15, 13, 17, 17),
#              'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 94,
#              'datetime': datetime.datetime(2021, 12, 16, 15, 38, 39),
#              'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 12, 16, 4, 35, 13),
#              'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 84,
#              'datetime': datetime.datetime(2021, 12, 16, 4, 34, 58),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 95,
#              'datetime': datetime.datetime(2021, 12, 16, 4, 34, 58),
#              'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 90,
#              'datetime': datetime.datetime(2021, 12, 16, 4, 34, 57),
#              'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 93,
#              'datetime': datetime.datetime(2021, 12, 16, 0, 21, 12),
#              'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 12, 16, 0, 21, 11),
#              'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 12, 16, 0, 20, 53),
#              'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 80,
#              'datetime': datetime.datetime(2021, 12, 25, 4, 29, 8),
#              'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 82,
#              'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#              'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 86,
#              'datetime': datetime.datetime(2021, 12, 27, 0, 2, 14),
#              'surface_temperature_celcius': 67}}

# %%
# 2.2e) Find the top 10 records with the highest surface temperature (°C).

pipeline = [
    # flatten hotspots
    {'$unwind': '$hotspot'},
    # sort descending order to get highest surface temperature from top
    {'$sort': {'hotspot.surface_temperature_celcius':pymongo.DESCENDING}},
    # only take top 10 records
    {'$limit':10}
]

result = collection.aggregate(pipeline=pipeline)
print_cursor(result)
# Out:
# {'GHI': 122,
#  '_id': ObjectId('628292f65b3178ab2dccec67'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2021, 4, 18, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 18, 4, 52),
#              'latitude': -38.1665,
#              'longitude': 143.062,
#              'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI': 140,
#  '_id': ObjectId('628292f65b3178ab2dccec59'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'latitude': -36.343,
#              'longitude': 142.1986,
#              'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI': 121,
#  '_id': ObjectId('628292f65b3178ab2dccec74'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2021, 5, 1, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 5, 1, 4, 14, 20),
#              'latitude': -36.9318,
#              'longitude': 143.0907,
#              'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI': 176,
#  '_id': ObjectId('628292f65b3178ab2dccec48'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2021, 3, 18, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 3, 18, 3, 50, 50),
#              'latitude': -37.017,
#              'longitude': 148.1297,
#              'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI': 140,
#  '_id': ObjectId('628292f65b3178ab2dccec59'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -36.3521,
#              'longitude': 142.2008,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI': 132,
#  '_id': ObjectId('628292f65b3178ab2dccec62'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2021, 4, 13, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 28, 10),
#              'latitude': -37.0745,
#              'longitude': 141.0692,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI': 81,
#  '_id': ObjectId('628292f65b3178ab2dccec80'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 5, 13, 4, 40, 20),
#              'latitude': -34.9938,
#              'longitude': 141.876,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI': 122,
#  '_id': ObjectId('628292f65b3178ab2dccec67'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2021, 4, 18, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 18, 4, 44, 50),
#              'latitude': -37.8326,
#              'longitude': 143.4999,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI': 140,
#  '_id': ObjectId('628292f65b3178ab2dccec59'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 40),
#              'latitude': -36.1057,
#              'longitude': 141.7608,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI': 91,
#  '_id': ObjectId('628292f65b3178ab2dccec77'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2021, 5, 4, 0, 0),
#  'hotspot': {'confidence': 100,
#              'datetime': datetime.datetime(2021, 5, 4, 4, 44, 50),
#              'latitude': -36.4057,
#              'longitude': 140.9806,
#              'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %%
# 2.2f) Find the number of fires each day. You are required to only display the total
# number of fires and the date in the output.

pipeline = [
    {'$project': {'_id':False, 
                  "date":{ "$dateToString":{"format":DATE_FORMAT, "date":"$date"}},
                  'count': {'$size': '$hotspot'}}},
]

result = collection.aggregate(pipeline=pipeline)

for record in result:
    formatted_output = {'date':record['date'], 'number_of_fires': record['count']}
    pprint(formatted_output)
# Out:
# {'date': '2020-12-31', 'number_of_fires': 0}
# {'date': '2021-01-01', 'number_of_fires': 0}
# {'date': '2021-01-02', 'number_of_fires': 0}
# {'date': '2021-01-03', 'number_of_fires': 0}
# {'date': '2021-01-04', 'number_of_fires': 0}
# {'date': '2021-01-05', 'number_of_fires': 0}
# {'date': '2021-01-06', 'number_of_fires': 0}
# {'date': '2021-01-07', 'number_of_fires': 0}
# {'date': '2021-01-08', 'number_of_fires': 0}
# {'date': '2021-01-09', 'number_of_fires': 0}
# {'date': '2021-01-10', 'number_of_fires': 0}
# {'date': '2021-01-11', 'number_of_fires': 0}
# {'date': '2021-01-12', 'number_of_fires': 0}
# {'date': '2021-01-13', 'number_of_fires': 0}
# {'date': '2021-01-14', 'number_of_fires': 0}
# {'date': '2021-01-15', 'number_of_fires': 0}
# {'date': '2021-01-16', 'number_of_fires': 0}
# {'date': '2021-01-17', 'number_of_fires': 0}
# {'date': '2021-01-18', 'number_of_fires': 0}
# {'date': '2021-01-19', 'number_of_fires': 0}
# {'date': '2021-01-20', 'number_of_fires': 0}
# {'date': '2021-01-21', 'number_of_fires': 0}
# {'date': '2021-01-22', 'number_of_fires': 0}
# {'date': '2021-01-23', 'number_of_fires': 0}
# {'date': '2021-01-24', 'number_of_fires': 0}
# {'date': '2021-01-25', 'number_of_fires': 0}
# {'date': '2021-01-26', 'number_of_fires': 0}
# {'date': '2021-01-27', 'number_of_fires': 0}
# {'date': '2021-01-28', 'number_of_fires': 0}
# {'date': '2021-01-29', 'number_of_fires': 0}
# {'date': '2021-01-30', 'number_of_fires': 0}
# {'date': '2021-01-31', 'number_of_fires': 0}
# {'date': '2021-02-01', 'number_of_fires': 0}
# {'date': '2021-02-02', 'number_of_fires': 0}
# {'date': '2021-02-03', 'number_of_fires': 0}
# {'date': '2021-02-04', 'number_of_fires': 0}
# {'date': '2021-02-05', 'number_of_fires': 0}
# {'date': '2021-02-06', 'number_of_fires': 0}
# {'date': '2021-02-07', 'number_of_fires': 0}
# {'date': '2021-02-08', 'number_of_fires': 0}
# {'date': '2021-02-09', 'number_of_fires': 0}
# {'date': '2021-02-10', 'number_of_fires': 0}
# {'date': '2021-02-11', 'number_of_fires': 0}
# {'date': '2021-02-12', 'number_of_fires': 0}
# {'date': '2021-02-13', 'number_of_fires': 0}
# {'date': '2021-02-14', 'number_of_fires': 0}
# {'date': '2021-02-15', 'number_of_fires': 0}
# {'date': '2021-02-16', 'number_of_fires': 0}
# {'date': '2021-02-17', 'number_of_fires': 0}
# {'date': '2021-02-18', 'number_of_fires': 0}
# {'date': '2021-02-19', 'number_of_fires': 0}
# {'date': '2021-02-20', 'number_of_fires': 0}
# {'date': '2021-02-21', 'number_of_fires': 0}
# {'date': '2021-02-22', 'number_of_fires': 0}
# {'date': '2021-02-23', 'number_of_fires': 0}
# {'date': '2021-02-24', 'number_of_fires': 0}
# {'date': '2021-02-25', 'number_of_fires': 0}
# {'date': '2021-02-26', 'number_of_fires': 0}
# {'date': '2021-02-27', 'number_of_fires': 0}
# {'date': '2021-02-28', 'number_of_fires': 0}
# {'date': '2021-03-01', 'number_of_fires': 0}
# {'date': '2021-03-02', 'number_of_fires': 0}
# {'date': '2021-03-03', 'number_of_fires': 0}
# {'date': '2021-03-04', 'number_of_fires': 0}
# {'date': '2021-03-05', 'number_of_fires': 0}
# {'date': '2021-03-06', 'number_of_fires': 2}
# {'date': '2021-03-07', 'number_of_fires': 1}
# {'date': '2021-03-08', 'number_of_fires': 2}
# {'date': '2021-03-09', 'number_of_fires': 3}
# {'date': '2021-03-10', 'number_of_fires': 8}
# {'date': '2021-03-11', 'number_of_fires': 0}
# {'date': '2021-03-12', 'number_of_fires': 5}
# {'date': '2021-03-13', 'number_of_fires': 2}
# {'date': '2021-03-14', 'number_of_fires': 10}
# {'date': '2021-03-15', 'number_of_fires': 7}
# {'date': '2021-03-16', 'number_of_fires': 0}
# {'date': '2021-03-17', 'number_of_fires': 6}
# {'date': '2021-03-18', 'number_of_fires': 3}
# {'date': '2021-03-19', 'number_of_fires': 21}
# {'date': '2021-03-20', 'number_of_fires': 0}
# {'date': '2021-03-21', 'number_of_fires': 0}
# {'date': '2021-03-22', 'number_of_fires': 0}
# {'date': '2021-03-23', 'number_of_fires': 0}
# {'date': '2021-03-24', 'number_of_fires': 2}
# {'date': '2021-03-25', 'number_of_fires': 13}
# {'date': '2021-03-26', 'number_of_fires': 17}
# {'date': '2021-03-27', 'number_of_fires': 0}
# {'date': '2021-03-28', 'number_of_fires': 54}
# {'date': '2021-03-29', 'number_of_fires': 1}
# {'date': '2021-03-30', 'number_of_fires': 0}
# {'date': '2021-03-31', 'number_of_fires': 22}
# {'date': '2021-04-01', 'number_of_fires': 7}
# {'date': '2021-04-02', 'number_of_fires': 5}
# {'date': '2021-04-03', 'number_of_fires': 72}
# {'date': '2021-04-04', 'number_of_fires': 89}
# {'date': '2021-04-05', 'number_of_fires': 49}
# {'date': '2021-04-06', 'number_of_fires': 118}
# {'date': '2021-04-07', 'number_of_fires': 39}
# {'date': '2021-04-08', 'number_of_fires': 20}
# {'date': '2021-04-09', 'number_of_fires': 0}
# {'date': '2021-04-10', 'number_of_fires': 0}
# {'date': '2021-04-11', 'number_of_fires': 24}
# {'date': '2021-04-12', 'number_of_fires': 69}
# {'date': '2021-04-13', 'number_of_fires': 357}
# {'date': '2021-04-14', 'number_of_fires': 18}
# {'date': '2021-04-15', 'number_of_fires': 69}
# {'date': '2021-04-16', 'number_of_fires': 18}
# {'date': '2021-04-17', 'number_of_fires': 38}
# {'date': '2021-04-18', 'number_of_fires': 325}
# {'date': '2021-04-19', 'number_of_fires': 50}
# {'date': '2021-04-20', 'number_of_fires': 31}
# {'date': '2021-04-21', 'number_of_fires': 0}
# {'date': '2021-04-22', 'number_of_fires': 2}
# {'date': '2021-04-23', 'number_of_fires': 19}
# {'date': '2021-04-24', 'number_of_fires': 8}
# {'date': '2021-04-25', 'number_of_fires': 3}
# {'date': '2021-04-26', 'number_of_fires': 1}
# {'date': '2021-04-27', 'number_of_fires': 0}
# {'date': '2021-04-28', 'number_of_fires': 0}
# {'date': '2021-04-29', 'number_of_fires': 3}
# {'date': '2021-04-30', 'number_of_fires': 0}
# {'date': '2021-05-01', 'number_of_fires': 20}
# {'date': '2021-05-02', 'number_of_fires': 10}
# {'date': '2021-05-03', 'number_of_fires': 64}
# {'date': '2021-05-04', 'number_of_fires': 135}
# {'date': '2021-05-05', 'number_of_fires': 31}
# {'date': '2021-05-06', 'number_of_fires': 17}
# {'date': '2021-05-07', 'number_of_fires': 3}
# {'date': '2021-05-08', 'number_of_fires': 24}
# {'date': '2021-05-09', 'number_of_fires': 13}
# {'date': '2021-05-10', 'number_of_fires': 114}
# {'date': '2021-05-11', 'number_of_fires': 19}
# {'date': '2021-05-12', 'number_of_fires': 10}
# {'date': '2021-05-13', 'number_of_fires': 54}
# {'date': '2021-05-14', 'number_of_fires': 1}
# {'date': '2021-05-15', 'number_of_fires': 102}
# {'date': '2021-05-16', 'number_of_fires': 3}
# {'date': '2021-05-17', 'number_of_fires': 1}
# {'date': '2021-05-18', 'number_of_fires': 7}
# {'date': '2021-05-19', 'number_of_fires': 0}
# {'date': '2021-05-20', 'number_of_fires': 0}
# {'date': '2021-05-21', 'number_of_fires': 0}
# {'date': '2021-05-22', 'number_of_fires': 33}
# {'date': '2021-05-23', 'number_of_fires': 5}
# {'date': '2021-05-24', 'number_of_fires': 3}
# {'date': '2021-05-25', 'number_of_fires': 0}
# {'date': '2021-05-26', 'number_of_fires': 4}
# {'date': '2021-05-27', 'number_of_fires': 0}
# {'date': '2021-05-28', 'number_of_fires': 0}
# {'date': '2021-05-29', 'number_of_fires': 0}
# {'date': '2021-05-30', 'number_of_fires': 0}
# {'date': '2021-05-31', 'number_of_fires': 0}
# {'date': '2021-06-01', 'number_of_fires': 2}
# {'date': '2021-06-02', 'number_of_fires': 11}
# {'date': '2021-06-03', 'number_of_fires': 2}
# {'date': '2021-06-04', 'number_of_fires': 9}
# {'date': '2021-06-05', 'number_of_fires': 0}
# {'date': '2021-06-06', 'number_of_fires': 0}
# {'date': '2021-06-07', 'number_of_fires': 14}
# {'date': '2021-06-08', 'number_of_fires': 0}
# {'date': '2021-06-09', 'number_of_fires': 3}
# {'date': '2021-06-10', 'number_of_fires': 0}
# {'date': '2021-06-11', 'number_of_fires': 2}
# {'date': '2021-06-12', 'number_of_fires': 0}
# {'date': '2021-06-13', 'number_of_fires': 1}
# {'date': '2021-06-14', 'number_of_fires': 4}
# {'date': '2021-06-15', 'number_of_fires': 0}
# {'date': '2021-06-16', 'number_of_fires': 2}
# {'date': '2021-06-17', 'number_of_fires': 0}
# {'date': '2021-06-18', 'number_of_fires': 2}
# {'date': '2021-06-19', 'number_of_fires': 0}
# {'date': '2021-06-20', 'number_of_fires': 6}
# {'date': '2021-06-21', 'number_of_fires': 0}
# {'date': '2021-06-22', 'number_of_fires': 1}
# {'date': '2021-06-23', 'number_of_fires': 0}
# {'date': '2021-06-24', 'number_of_fires': 0}
# {'date': '2021-06-25', 'number_of_fires': 0}
# {'date': '2021-06-26', 'number_of_fires': 0}
# {'date': '2021-06-27', 'number_of_fires': 0}
# {'date': '2021-06-28', 'number_of_fires': 0}
# {'date': '2021-06-29', 'number_of_fires': 0}
# {'date': '2021-06-30', 'number_of_fires': 6}
# {'date': '2021-07-01', 'number_of_fires': 4}
# {'date': '2021-07-02', 'number_of_fires': 8}
# {'date': '2021-07-03', 'number_of_fires': 0}
# {'date': '2021-07-04', 'number_of_fires': 1}
# {'date': '2021-07-05', 'number_of_fires': 1}
# {'date': '2021-07-06', 'number_of_fires': 3}
# {'date': '2021-07-07', 'number_of_fires': 0}
# {'date': '2021-07-08', 'number_of_fires': 0}
# {'date': '2021-07-09', 'number_of_fires': 0}
# {'date': '2021-07-10', 'number_of_fires': 0}
# {'date': '2021-07-11', 'number_of_fires': 0}
# {'date': '2021-07-12', 'number_of_fires': 0}
# {'date': '2021-07-13', 'number_of_fires': 0}
# {'date': '2021-07-14', 'number_of_fires': 2}
# {'date': '2021-07-15', 'number_of_fires': 0}
# {'date': '2021-07-16', 'number_of_fires': 0}
# {'date': '2021-07-17', 'number_of_fires': 0}
# {'date': '2021-07-18', 'number_of_fires': 0}
# {'date': '2021-07-19', 'number_of_fires': 0}
# {'date': '2021-07-20', 'number_of_fires': 0}
# {'date': '2021-07-21', 'number_of_fires': 0}
# {'date': '2021-07-22', 'number_of_fires': 0}
# {'date': '2021-07-23', 'number_of_fires': 0}
# {'date': '2021-07-24', 'number_of_fires': 0}
# {'date': '2021-07-25', 'number_of_fires': 0}
# {'date': '2021-07-26', 'number_of_fires': 0}
# {'date': '2021-07-27', 'number_of_fires': 0}
# {'date': '2021-07-28', 'number_of_fires': 0}
# {'date': '2021-07-29', 'number_of_fires': 2}
# {'date': '2021-07-30', 'number_of_fires': 0}
# {'date': '2021-07-31', 'number_of_fires': 2}
# {'date': '2021-08-01', 'number_of_fires': 2}
# {'date': '2021-08-02', 'number_of_fires': 2}
# {'date': '2021-08-03', 'number_of_fires': 0}
# {'date': '2021-08-04', 'number_of_fires': 0}
# {'date': '2021-08-05', 'number_of_fires': 1}
# {'date': '2021-08-06', 'number_of_fires': 0}
# {'date': '2021-08-07', 'number_of_fires': 0}
# {'date': '2021-08-08', 'number_of_fires': 0}
# {'date': '2021-08-09', 'number_of_fires': 0}
# {'date': '2021-08-10', 'number_of_fires': 1}
# {'date': '2021-08-11', 'number_of_fires': 0}
# {'date': '2021-08-12', 'number_of_fires': 0}
# {'date': '2021-08-13', 'number_of_fires': 9}
# {'date': '2021-08-14', 'number_of_fires': 5}
# {'date': '2021-08-15', 'number_of_fires': 0}
# {'date': '2021-08-16', 'number_of_fires': 0}
# {'date': '2021-08-17', 'number_of_fires': 0}
# {'date': '2021-08-18', 'number_of_fires': 0}
# {'date': '2021-08-19', 'number_of_fires': 0}
# {'date': '2021-08-20', 'number_of_fires': 0}
# {'date': '2021-08-21', 'number_of_fires': 0}
# {'date': '2021-08-22', 'number_of_fires': 0}
# {'date': '2021-08-23', 'number_of_fires': 0}
# {'date': '2021-08-24', 'number_of_fires': 0}
# {'date': '2021-08-25', 'number_of_fires': 0}
# {'date': '2021-08-26', 'number_of_fires': 0}
# {'date': '2021-08-27', 'number_of_fires': 0}
# {'date': '2021-08-28', 'number_of_fires': 0}
# {'date': '2021-08-29', 'number_of_fires': 0}
# {'date': '2021-08-30', 'number_of_fires': 0}
# {'date': '2021-08-31', 'number_of_fires': 0}
# {'date': '2021-09-01', 'number_of_fires': 0}
# {'date': '2021-09-02', 'number_of_fires': 0}
# {'date': '2021-09-03', 'number_of_fires': 0}
# {'date': '2021-09-04', 'number_of_fires': 0}
# {'date': '2021-09-05', 'number_of_fires': 0}
# {'date': '2021-09-06', 'number_of_fires': 0}
# {'date': '2021-09-07', 'number_of_fires': 0}
# {'date': '2021-09-08', 'number_of_fires': 0}
# {'date': '2021-09-09', 'number_of_fires': 0}
# {'date': '2021-09-10', 'number_of_fires': 4}
# {'date': '2021-09-11', 'number_of_fires': 0}
# {'date': '2021-09-12', 'number_of_fires': 0}
# {'date': '2021-09-13', 'number_of_fires': 0}
# {'date': '2021-09-14', 'number_of_fires': 0}
# {'date': '2021-09-15', 'number_of_fires': 0}
# {'date': '2021-09-16', 'number_of_fires': 0}
# {'date': '2021-09-17', 'number_of_fires': 0}
# {'date': '2021-09-18', 'number_of_fires': 0}
# {'date': '2021-09-19', 'number_of_fires': 0}
# {'date': '2021-09-20', 'number_of_fires': 5}
# {'date': '2021-09-21', 'number_of_fires': 2}
# {'date': '2021-09-22', 'number_of_fires': 1}
# {'date': '2021-09-23', 'number_of_fires': 23}
# {'date': '2021-09-24', 'number_of_fires': 28}
# {'date': '2021-09-25', 'number_of_fires': 0}
# {'date': '2021-09-26', 'number_of_fires': 1}
# {'date': '2021-09-27', 'number_of_fires': 7}
# {'date': '2021-09-28', 'number_of_fires': 0}
# {'date': '2021-09-29', 'number_of_fires': 2}
# {'date': '2021-09-30', 'number_of_fires': 0}
# {'date': '2021-10-01', 'number_of_fires': 8}
# {'date': '2021-10-02', 'number_of_fires': 7}
# {'date': '2021-10-03', 'number_of_fires': 18}
# {'date': '2021-10-04', 'number_of_fires': 5}
# {'date': '2021-10-05', 'number_of_fires': 0}
# {'date': '2021-10-06', 'number_of_fires': 2}
# {'date': '2021-10-07', 'number_of_fires': 1}
# {'date': '2021-10-08', 'number_of_fires': 1}
# {'date': '2021-10-09', 'number_of_fires': 1}
# {'date': '2021-10-10', 'number_of_fires': 3}
# {'date': '2021-10-11', 'number_of_fires': 0}
# {'date': '2021-10-12', 'number_of_fires': 0}
# {'date': '2021-10-13', 'number_of_fires': 0}
# {'date': '2021-10-14', 'number_of_fires': 0}
# {'date': '2021-10-15', 'number_of_fires': 3}
# {'date': '2021-10-16', 'number_of_fires': 1}
# {'date': '2021-10-17', 'number_of_fires': 5}
# {'date': '2021-10-18', 'number_of_fires': 6}
# {'date': '2021-10-19', 'number_of_fires': 0}
# {'date': '2021-10-20', 'number_of_fires': 3}
# {'date': '2021-10-21', 'number_of_fires': 4}
# {'date': '2021-10-22', 'number_of_fires': 0}
# {'date': '2021-10-23', 'number_of_fires': 1}
# {'date': '2021-10-24', 'number_of_fires': 0}
# {'date': '2021-10-25', 'number_of_fires': 0}
# {'date': '2021-10-26', 'number_of_fires': 5}
# {'date': '2021-10-27', 'number_of_fires': 5}
# {'date': '2021-10-28', 'number_of_fires': 1}
# {'date': '2021-10-29', 'number_of_fires': 0}
# {'date': '2021-10-30', 'number_of_fires': 0}
# {'date': '2021-10-31', 'number_of_fires': 0}
# {'date': '2021-11-01', 'number_of_fires': 0}
# {'date': '2021-11-02', 'number_of_fires': 0}
# {'date': '2021-11-03', 'number_of_fires': 0}
# {'date': '2021-11-04', 'number_of_fires': 0}
# {'date': '2021-11-05', 'number_of_fires': 4}
# {'date': '2021-11-06', 'number_of_fires': 0}
# {'date': '2021-11-07', 'number_of_fires': 0}
# {'date': '2021-11-08', 'number_of_fires': 2}
# {'date': '2021-11-09', 'number_of_fires': 10}
# {'date': '2021-11-10', 'number_of_fires': 0}
# {'date': '2021-11-11', 'number_of_fires': 4}
# {'date': '2021-11-12', 'number_of_fires': 5}
# {'date': '2021-11-13', 'number_of_fires': 5}
# {'date': '2021-11-14', 'number_of_fires': 3}
# {'date': '2021-11-15', 'number_of_fires': 0}
# {'date': '2021-11-16', 'number_of_fires': 0}
# {'date': '2021-11-17', 'number_of_fires': 0}
# {'date': '2021-11-18', 'number_of_fires': 0}
# {'date': '2021-11-19', 'number_of_fires': 0}
# {'date': '2021-11-20', 'number_of_fires': 0}
# {'date': '2021-11-21', 'number_of_fires': 1}
# {'date': '2021-11-22', 'number_of_fires': 2}
# {'date': '2021-11-23', 'number_of_fires': 5}
# {'date': '2021-11-24', 'number_of_fires': 0}
# {'date': '2021-11-25', 'number_of_fires': 0}
# {'date': '2021-11-26', 'number_of_fires': 0}
# {'date': '2021-11-27', 'number_of_fires': 0}
# {'date': '2021-11-28', 'number_of_fires': 1}
# {'date': '2021-11-29', 'number_of_fires': 8}
# {'date': '2021-11-30', 'number_of_fires': 31}
# {'date': '2021-12-01', 'number_of_fires': 0}
# {'date': '2021-12-02', 'number_of_fires': 0}
# {'date': '2021-12-03', 'number_of_fires': 0}
# {'date': '2021-12-04', 'number_of_fires': 0}
# {'date': '2021-12-05', 'number_of_fires': 0}
# {'date': '2021-12-06', 'number_of_fires': 0}
# {'date': '2021-12-07', 'number_of_fires': 0}
# {'date': '2021-12-08', 'number_of_fires': 5}
# {'date': '2021-12-09', 'number_of_fires': 4}
# {'date': '2021-12-10', 'number_of_fires': 2}
# {'date': '2021-12-11', 'number_of_fires': 0}
# {'date': '2021-12-12', 'number_of_fires': 1}
# {'date': '2021-12-13', 'number_of_fires': 1}
# {'date': '2021-12-14', 'number_of_fires': 1}
# {'date': '2021-12-15', 'number_of_fires': 4}
# {'date': '2021-12-16', 'number_of_fires': 15}
# {'date': '2021-12-17', 'number_of_fires': 0}
# {'date': '2021-12-18', 'number_of_fires': 0}
# {'date': '2021-12-19', 'number_of_fires': 0}
# {'date': '2021-12-20', 'number_of_fires': 0}
# {'date': '2021-12-21', 'number_of_fires': 1}
# {'date': '2021-12-22', 'number_of_fires': 0}
# {'date': '2021-12-23', 'number_of_fires': 0}
# {'date': '2021-12-24', 'number_of_fires': 1}
# {'date': '2021-12-25', 'number_of_fires': 1}
# {'date': '2021-12-26', 'number_of_fires': 0}
# {'date': '2021-12-27', 'number_of_fires': 4}
# {'date': '2021-12-28', 'number_of_fires': 0}
# {'date': '2021-12-29', 'number_of_fires': 0}
# {'date': '2021-12-30', 'number_of_fires': 0}
# {'date': '2021-12-31', 'number_of_fires': 0}

# %%
# 2.2g) Find the records of fires where the confidence is below 70

pipeline = [
    # flatten hotspots
    {'$unwind': '$hotspot'},
    # filter for valid confidence levels
    {'$match': { 'hotspot.confidence':{'$lte': 70} } },
    # we only want the record of fire
    {'$project': {'_id':False, 'hotspot':True}}
]

result = collection.aggregate(pipeline=pipeline)
print_cursor(result)
# Out:
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 3, 8, 4, 51),
#              'latitude': -37.7885,
#              'longitude': 141.9352,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 54,
#              'datetime': datetime.datetime(2021, 3, 9, 3, 57),
#              'latitude': -37.7171,
#              'longitude': 147.5866,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 55,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 43),
#              'latitude': -36.2544,
#              'longitude': 148.0353,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 54,
#              'datetime': datetime.datetime(2021, 3, 10, 4, 42, 30),
#              'latitude': -37.2197,
#              'longitude': 147.9621,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 3, 13, 23, 58, 50),
#              'latitude': -37.0286,
#              'longitude': 148.155,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 3, 13, 12, 57),
#              'latitude': -37.0316,
#              'longitude': 148.1519,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 3, 15, 0, 42, 50),
#              'latitude': -37.4075,
#              'longitude': 147.0233,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 3, 15, 0, 42, 50),
#              'latitude': -37.0228,
#              'longitude': 148.1281,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 3, 15, 0, 42, 40),
#              'latitude': -37.002,
#              'longitude': 148.2055,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 3, 15, 0, 37, 20),
#              'latitude': -37.4098,
#              'longitude': 147.0489,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 3, 18, 13, 16, 50),
#              'latitude': -37.4313,
#              'longitude': 147.0343,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#              'latitude': -37.9164,
#              'longitude': 143.4866,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#              'latitude': -37.9257,
#              'longitude': 143.4891,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 36),
#              'latitude': -37.3982,
#              'longitude': 147.0001,
#              'surface_temperature_celcius': 58}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 35),
#              'latitude': -37.4023,
#              'longitude': 147.0394,
#              'surface_temperature_celcius': 56}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 33, 50),
#              'latitude': -37.4336,
#              'longitude': 147.0534,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 33, 30),
#              'latitude': -37.4003,
#              'longitude': 147.0448,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 33, 30),
#              'latitude': -37.9184,
#              'longitude': 143.4745,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 33, 10),
#              'latitude': -37.3911,
#              'longitude': 147.037,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#              'latitude': -37.9277,
#              'longitude': 143.477,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 3, 19, 0, 12, 50),
#              'latitude': -37.3942,
#              'longitude': 147.0455,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 3, 24, 4, 58),
#              'latitude': -37.1603,
#              'longitude': 142.8088,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 55,
#              'datetime': datetime.datetime(2021, 3, 24, 4, 56, 10),
#              'latitude': -37.1684,
#              'longitude': 142.8183,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 3, 25, 4, 3, 10),
#              'latitude': -37.8992,
#              'longitude': 143.4534,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 3, 25, 3, 56, 40),
#              'latitude': -37.9022,
#              'longitude': 143.4607,
#              'surface_temperature_celcius': 57}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 41, 10),
#              'latitude': -38.1131,
#              'longitude': 143.7173,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'latitude': -37.8469,
#              'longitude': 143.5343,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#              'latitude': -37.1956,
#              'longitude': 141.0252,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 31, 50),
#              'latitude': -36.9576,
#              'longitude': 141.5387,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 29, 30),
#              'latitude': -37.6195,
#              'longitude': 143.4212,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'latitude': -37.6376,
#              'longitude': 143.4255,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'latitude': -36.4422,
#              'longitude': 141.4172,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 55,
#              'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#              'latitude': -34.342,
#              'longitude': 141.6548,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 3, 29, 0, 48, 40),
#              'latitude': -34.2648,
#              'longitude': 141.6325,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 50),
#              'latitude': -36.1649,
#              'longitude': 145.9352,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 40),
#              'latitude': -36.0436,
#              'longitude': 145.7964,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 40),
#              'latitude': -36.0362,
#              'longitude': 145.7984,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#              'latitude': -36.7134,
#              'longitude': 145.2151,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#              'latitude': -36.7028,
#              'longitude': 145.2519,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#              'latitude': -37.561,
#              'longitude': 143.242,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#              'latitude': -37.982,
#              'longitude': 143.6422,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 3, 31, 0, 36, 30),
#              'latitude': -34.2568,
#              'longitude': 141.64,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 1, 4, 9, 20),
#              'latitude': -36.2721,
#              'longitude': 146.847,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 4, 1, 4, 2, 40),
#              'latitude': -36.2044,
#              'longitude': 145.7706,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 1, 4, 2, 40),
#              'latitude': -36.5245,
#              'longitude': 143.1556,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 1, 4, 2, 40),
#              'latitude': -36.1002,
#              'longitude': 147.6494,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 2, 4, 53, 30),
#              'latitude': -36.3872,
#              'longitude': 145.3858,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 2, 4, 45, 10),
#              'latitude': -36.494,
#              'longitude': 145.4522,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 2, 0, 24, 50),
#              'latitude': -37.324,
#              'longitude': 146.1647,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 53, 50),
#              'latitude': -37.8668,
#              'longitude': 143.0472,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 53, 40),
#              'latitude': -37.7602,
#              'longitude': 143.382,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 53, 30),
#              'latitude': -37.7885,
#              'longitude': 142.9509,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 52, 10),
#              'latitude': -37.8717,
#              'longitude': 143.2566,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 51, 10),
#              'latitude': -37.8011,
#              'longitude': 144.7343,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#              'latitude': -37.0241,
#              'longitude': 141.5163,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#              'latitude': -37.2912,
#              'longitude': 143.543,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#              'latitude': -37.313,
#              'longitude': 146.1561,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#              'latitude': -38.0226,
#              'longitude': 143.6739,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'latitude': -37.8089,
#              'longitude': 145.9555,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'latitude': -37.9009,
#              'longitude': 143.6217,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'latitude': -37.7583,
#              'longitude': 143.41,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'latitude': -37.7836,
#              'longitude': 142.9437,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'latitude': -37.0484,
#              'longitude': 141.6245,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#              'latitude': -36.911,
#              'longitude': 142.1445,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 3, 1, 11),
#              'latitude': -34.2536,
#              'longitude': 141.6199,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 3, 1, 7),
#              'latitude': -34.2614,
#              'longitude': 141.6412,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 4, 15, 30, 40),
#              'latitude': -36.0933,
#              'longitude': 141.7154,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 50),
#              'latitude': -36.6281,
#              'longitude': 142.4349,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 40),
#              'latitude': -36.937,
#              'longitude': 142.1176,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 39, 20),
#              'latitude': -38.1868,
#              'longitude': 143.0938,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 38, 10),
#              'latitude': -36.6951,
#              'longitude': 145.424,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 36, 30),
#              'latitude': -37.6714,
#              'longitude': 144.2154,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 36, 30),
#              'latitude': -37.4465,
#              'longitude': 143.5163,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 36, 30),
#              'latitude': -38.0494,
#              'longitude': 143.9141,
#              'surface_temperature_celcius': 58}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34, 30),
#              'latitude': -36.8848,
#              'longitude': 142.1523,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 54,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 34, 20),
#              'latitude': -38.4879,
#              'longitude': 143.9971,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 30),
#              'latitude': -37.1744,
#              'longitude': 143.9256,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 30),
#              'latitude': -36.4918,
#              'longitude': 142.2465,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 10),
#              'latitude': -36.6299,
#              'longitude': 142.4234,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 33, 10),
#              'latitude': -36.1439,
#              'longitude': 145.832,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 54,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'latitude': -36.7009,
#              'longitude': 141.541,
#              'surface_temperature_celcius': 49}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#              'latitude': -36.4604,
#              'longitude': 142.1623,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 55,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -36.4611,
#              'longitude': 143.146,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -36.3539,
#              'longitude': 142.1894,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -37.0081,
#              'longitude': 141.7654,
#              'surface_temperature_celcius': 62}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -36.2889,
#              'longitude': 141.7692,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -36.6228,
#              'longitude': 142.428,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#              'latitude': -38.1177,
#              'longitude': 143.6409,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 10, 10),
#              'latitude': -38.3499,
#              'longitude': 147.033,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 2, 50),
#              'latitude': -38.3483,
#              'longitude': 147.0446,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 5, 13, 2, 40),
#              'latitude': -37.6435,
#              'longitude': 146.1417,
#              'surface_temperature_celcius': 36}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 5, 5, 15, 40),
#              'latitude': -37.7522,
#              'longitude': 142.3183,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 5, 5, 15, 30),
#              'latitude': -36.9396,
#              'longitude': 141.9303,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 45, 10),
#              'latitude': -37.78,
#              'longitude': 141.8091,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 44, 40),
#              'latitude': -37.7767,
#              'longitude': 141.8127,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 44, 30),
#              'latitude': -38.1756,
#              'longitude': 143.9829,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 40, 40),
#              'latitude': -36.9373,
#              'longitude': 142.5327,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 40, 30),
#              'latitude': -38.3553,
#              'longitude': 147.0231,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 40, 30),
#              'latitude': -36.934,
#              'longitude': 142.5759,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'latitude': -38.0383,
#              'longitude': 144.4307,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'latitude': -36.9354,
#              'longitude': 142.5807,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'latitude': -36.9405,
#              'longitude': 142.8627,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 5, 3, 39, 10),
#              'latitude': -37.6339,
#              'longitude': 143.4108,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 25, 40),
#              'latitude': -37.7069,
#              'longitude': 142.1573,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 25, 40),
#              'latitude': -36.0834,
#              'longitude': 146.5364,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 50),
#              'latitude': -36.3557,
#              'longitude': 141.3268,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 50),
#              'latitude': -37.6104,
#              'longitude': 147.8367,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 50),
#              'latitude': -37.9229,
#              'longitude': 143.647,
#              'surface_temperature_celcius': 63}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 23, 50),
#              'latitude': -37.5052,
#              'longitude': 142.8636,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 22, 20),
#              'latitude': -37.8177,
#              'longitude': 142.9168,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21, 20),
#              'latitude': -37.5842,
#              'longitude': 148.5717,
#              'surface_temperature_celcius': 49}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21, 20),
#              'latitude': -37.9483,
#              'longitude': 145.3937,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21),
#              'latitude': -38.0089,
#              'longitude': 143.8976,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 21),
#              'latitude': -37.3072,
#              'longitude': 147.5003,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 50),
#              'latitude': -37.3556,
#              'longitude': 146.1085,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -37.6806,
#              'longitude': 143.2676,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -37.7212,
#              'longitude': 145.9754,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -38.3343,
#              'longitude': 143.8644,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -35.723,
#              'longitude': 142.063,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -35.1383,
#              'longitude': 141.8172,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -36.4133,
#              'longitude': 141.0286,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -36.6492,
#              'longitude': 142.3976,
#              'surface_temperature_celcius': 60}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -36.0765,
#              'longitude': 146.4896,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -36.0799,
#              'longitude': 146.529,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -36.8632,
#              'longitude': 142.5802,
#              'surface_temperature_celcius': 60}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -37.1929,
#              'longitude': 143.8132,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -37.1992,
#              'longitude': 146.2301,
#              'surface_temperature_celcius': 60}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -37.5914,
#              'longitude': 148.5807,
#              'surface_temperature_celcius': 61}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 6, 4, 20, 40),
#              'latitude': -37.7496,
#              'longitude': 148.3898,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 6, 0, 3, 50),
#              'latitude': -35.4625,
#              'longitude': 143.1486,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 4, 6, 0, 1, 40),
#              'latitude': -38.0942,
#              'longitude': 146.9603,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 53, 40),
#              'latitude': -35.6961,
#              'longitude': 143.1935,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 52, 10),
#              'latitude': -37.3314,
#              'longitude': 149.1283,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 51, 20),
#              'latitude': -37.3359,
#              'longitude': 149.3816,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 51),
#              'latitude': -37.3526,
#              'longitude': 149.3972,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 50, 40),
#              'latitude': -37.3344,
#              'longitude': 149.3933,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 50, 40),
#              'latitude': -37.3511,
#              'longitude': 149.4088,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 7, 12, 50, 40),
#              'latitude': -36.7508,
#              'longitude': 147.1254,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 7, 5, 3, 10),
#              'latitude': -36.1031,
#              'longitude': 143.0782,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 7, 5, 3, 10),
#              'latitude': -36.1025,
#              'longitude': 143.0825,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 7, 5, 3, 10),
#              'latitude': -36.7314,
#              'longitude': 141.8698,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 7, 3, 31, 40),
#              'latitude': -37.7931,
#              'longitude': 148.385,
#              'surface_temperature_celcius': 58}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 7, 3, 27, 50),
#              'latitude': -37.7974,
#              'longitude': 148.5498,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 15, 20),
#              'latitude': -37.34,
#              'longitude': 149.3668,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 14, 40),
#              'latitude': -37.8567,
#              'longitude': 147.1576,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 12, 20),
#              'latitude': -37.4368,
#              'longitude': 149.1191,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 11, 40),
#              'latitude': -37.9408,
#              'longitude': 146.0611,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 9, 20),
#              'latitude': -37.6994,
#              'longitude': 146.2162,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 8, 50),
#              'latitude': -36.7199,
#              'longitude': 142.5844,
#              'surface_temperature_celcius': 56}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 8, 40),
#              'latitude': -37.3493,
#              'longitude': 149.3691,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 4, 8, 4, 8, 40),
#              'latitude': -37.6447,
#              'longitude': 148.6039,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 50, 20),
#              'latitude': -36.2282,
#              'longitude': 145.9074,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 42, 10),
#              'latitude': -36.3499,
#              'longitude': 146.1402,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 40, 30),
#              'latitude': -36.4439,
#              'longitude': 145.8846,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 39, 40),
#              'latitude': -36.0818,
#              'longitude': 146.5461,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.343,
#              'longitude': 143.3479,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.1751,
#              'longitude': 142.7831,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 55,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.4606,
#              'longitude': 141.0562,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 66,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.0156,
#              'longitude': 143.2188,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.1398,
#              'longitude': 141.7793,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -35.2068,
#              'longitude': 143.2912,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.3579,
#              'longitude': 146.1268,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 11, 4, 38, 50),
#              'latitude': -36.0787,
#              'longitude': 146.5728,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 11, 0, 20, 30),
#              'latitude': -37.9796,
#              'longitude': 146.8024,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 12, 13, 13, 10),
#              'latitude': -35.4309,
#              'longitude': 142.3626,
#              'surface_temperature_celcius': 36}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 12, 13, 9, 20),
#              'latitude': -35.4407,
#              'longitude': 142.3644,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 28),
#              'latitude': -37.4755,
#              'longitude': 142.6339,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 54,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 26, 50),
#              'latitude': -36.7453,
#              'longitude': 141.4578,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 25),
#              'latitude': -36.7038,
#              'longitude': 141.0498,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 23, 10),
#              'latitude': -37.4785,
#              'longitude': 142.6307,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 21, 50),
#              'latitude': -37.7578,
#              'longitude': 142.227,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 21, 40),
#              'latitude': -36.8083,
#              'longitude': 142.0219,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 21, 40),
#              'latitude': -36.714,
#              'longitude': 141.1485,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 12, 5, 21, 40),
#              'latitude': -36.7318,
#              'longitude': 141.4603,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 51),
#              'latitude': -36.6385,
#              'longitude': 142.5297,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 50, 10),
#              'latitude': -36.9179,
#              'longitude': 141.3095,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 47, 30),
#              'latitude': -36.6348,
#              'longitude': 142.4985,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 46, 50),
#              'latitude': -37.3654,
#              'longitude': 143.8156,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 46, 20),
#              'latitude': -36.6188,
#              'longitude': 144.0402,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 46),
#              'latitude': -37.4047,
#              'longitude': 143.6615,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 46),
#              'latitude': -36.2367,
#              'longitude': 141.3998,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 45, 10),
#              'latitude': -36.5234,
#              'longitude': 144.6939,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 45),
#              'latitude': -36.6803,
#              'longitude': 141.0957,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 50),
#              'latitude': -36.7866,
#              'longitude': 142.1989,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -36.6292,
#              'longitude': 143.8862,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -35.7937,
#              'longitude': 143.195,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -36.9142,
#              'longitude': 141.3013,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -36.6306,
#              'longitude': 143.8908,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -37.3586,
#              'longitude': 142.9087,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -36.9524,
#              'longitude': 143.7501,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -37.0643,
#              'longitude': 141.8567,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -36.2403,
#              'longitude': 141.4047,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -36.6776,
#              'longitude': 141.0877,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -37.7929,
#              'longitude': 143.1197,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -37.7972,
#              'longitude': 143.1153,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 12, 3, 44, 40),
#              'latitude': -37.3656,
#              'longitude': 143.8206,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 36, 30),
#              'latitude': -37.8865,
#              'longitude': 143.3048,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 36, 20),
#              'latitude': -36.5414,
#              'longitude': 145.4159,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 36, 20),
#              'latitude': -37.5687,
#              'longitude': 143.2121,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 34, 50),
#              'latitude': -37.7359,
#              'longitude': 143.0108,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 50),
#              'latitude': -37.1009,
#              'longitude': 141.9666,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 50),
#              'latitude': -36.9211,
#              'longitude': 143.6017,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 30),
#              'latitude': -38.211,
#              'longitude': 143.9122,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 30),
#              'latitude': -37.7576,
#              'longitude': 142.465,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 20),
#              'latitude': -38.0505,
#              'longitude': 142.4791,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 10),
#              'latitude': -37.7851,
#              'longitude': 141.4593,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 10),
#              'latitude': -37.9075,
#              'longitude': 142.6403,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33, 10),
#              'latitude': -37.8345,
#              'longitude': 142.447,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 33),
#              'latitude': -37.7871,
#              'longitude': 142.718,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 31, 30),
#              'latitude': -36.8573,
#              'longitude': 143.5278,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 29, 50),
#              'latitude': -37.0207,
#              'longitude': 141.4778,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 29, 40),
#              'latitude': -37.6857,
#              'longitude': 142.8532,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 29, 40),
#              'latitude': -37.2709,
#              'longitude': 143.9659,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 29, 40),
#              'latitude': -37.5632,
#              'longitude': 142.2864,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 29, 30),
#              'latitude': -36.3305,
#              'longitude': 146.049,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 29, 20),
#              'latitude': -38.0132,
#              'longitude': 143.2528,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 57,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 28, 30),
#              'latitude': -38.0643,
#              'longitude': 143.6616,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 28, 30),
#              'latitude': -37.9898,
#              'longitude': 143.8507,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 28, 10),
#              'latitude': -37.0667,
#              'longitude': 143.0582,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 4, 13, 4, 28, 10),
#              'latitude': -36.5548,
#              'longitude': 142.5237,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 60,
# ...
#              'latitude': -37.434,
#              'longitude': 148.091,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#              'latitude': -37.375,
#              'longitude': 148.063,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 9, 24, 4, 4, 19),
#              'latitude': -37.397,
#              'longitude': 148.121,
#              'surface_temperature_celcius': 58}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#              'latitude': -37.452,
#              'longitude': 148.115,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#              'latitude': -37.465,
#              'longitude': 148.153,
#              'surface_temperature_celcius': 63}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#              'latitude': -37.45,
#              'longitude': 148.126,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 9, 24, 4, 4, 17),
#              'latitude': -37.562,
#              'longitude': 148.05,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 9, 24, 4, 4, 4),
#              'latitude': -38.495,
#              'longitude': 146.944,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 9, 26, 3, 52, 14),
#              'latitude': -37.087,
#              'longitude': 145.37,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 9, 27, 4, 35, 18),
#              'latitude': -36.398,
#              'longitude': 145.286,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 9, 29, 4, 22, 41),
#              'latitude': -37.45,
#              'longitude': 148.097,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 10, 1, 15, 13, 56),
#              'latitude': -37.463,
#              'longitude': 148.109,
#              'surface_temperature_celcius': 34}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#              'latitude': -37.46,
#              'longitude': 148.113,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 10, 2, 23, 44, 31),
#              'latitude': -37.466,
#              'longitude': 148.1,
#              'surface_temperature_celcius': 29}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 10, 2, 4, 53, 10),
#              'latitude': -37.475,
#              'longitude': 148.134,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 10, 2, 0, 39, 34),
#              'latitude': -37.456,
#              'longitude': 148.11,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 10, 3, 15, 1, 44),
#              'latitude': -37.461,
#              'longitude': 148.109,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 10, 3, 3, 58, 28),
#              'latitude': -37.236,
#              'longitude': 141.176,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 10, 3, 3, 58, 28),
#              'latitude': -37.227,
#              'longitude': 141.151,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 54,
#              'datetime': datetime.datetime(2021, 10, 3, 1, 22, 44),
#              'latitude': -37.227,
#              'longitude': 141.146,
#              'surface_temperature_celcius': 31}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 10, 4, 4, 41, 36),
#              'latitude': -36.418,
#              'longitude': 141.596,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 10, 16, 23, 56, 43),
#              'latitude': -37.288,
#              'longitude': 144.39,
#              'surface_temperature_celcius': 36}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 10, 17, 4, 10, 38),
#              'latitude': -37.587,
#              'longitude': 142.479,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 10, 20, 0, 27, 12),
#              'latitude': -37.296,
#              'longitude': 144.386,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 10, 21, 1, 9, 54),
#              'latitude': -36.1,
#              'longitude': 143.772,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 10, 26, 4, 4, 53),
#              'latitude': -36.156,
#              'longitude': 143.568,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 10, 26, 4, 4, 53),
#              'latitude': -36.152,
#              'longitude': 143.578,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 10, 27, 4, 47, 31),
#              'latitude': -36.748,
#              'longitude': 144.168,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 11, 8, 5, 12, 8),
#              'latitude': -36.538,
#              'longitude': 141.129,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 56),
#              'latitude': -36.759,
#              'longitude': 145.179,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 56),
#              'latitude': -36.758,
#              'longitude': 145.19,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 11, 9, 4, 16, 46),
#              'latitude': -37.719,
#              'longitude': 142.154,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 11, 11, 15, 8),
#              'latitude': -36.943,
#              'longitude': 143.286,
#              'surface_temperature_celcius': 29}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 11, 12, 4, 47, 32),
#              'latitude': -36.942,
#              'longitude': 143.282,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 58,
#              'datetime': datetime.datetime(2021, 11, 12, 4, 47, 16),
#              'latitude': -37.864,
#              'longitude': 144.174,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 11, 12, 4, 46, 53),
#              'latitude': -38.912,
#              'longitude': 146.272,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 11, 12, 0, 33, 15),
#              'latitude': -36.942,
#              'longitude': 143.292,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 13, 3, 52, 8),
#              'latitude': -37.954,
#              'longitude': 143.918,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 11, 13, 1, 16, 38),
#              'latitude': -38.167,
#              'longitude': 143.841,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 11, 13, 1, 16, 37),
#              'latitude': -38.16,
#              'longitude': 143.803,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 14, 0, 21, 26),
#              'latitude': -38.527,
#              'longitude': 143.493,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 14, 0, 21, 7),
#              'latitude': -37.332,
#              'longitude': 143.375,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 11, 23, 0, 15, 12),
#              'latitude': -38.141,
#              'longitude': 143.183,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 63,
#              'datetime': datetime.datetime(2021, 11, 23, 0, 14, 47),
#              'latitude': -36.952,
#              'longitude': 144.972,
#              'surface_temperature_celcius': 60}}
# {'hotspot': {'confidence': 70,
#              'datetime': datetime.datetime(2021, 11, 23, 0, 14, 24),
#              'latitude': -34.965,
#              'longitude': 142.031,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 11, 28, 0, 33, 14),
#              'latitude': -37.749,
#              'longitude': 148.297,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#              'latitude': -37.611,
#              'longitude': 149.277,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 68,
#              'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#              'latitude': -37.605,
#              'longitude': 149.308,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 11, 29, 3, 53, 16),
#              'latitude': -34.282,
#              'longitude': 142.121,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#              'latitude': -37.605,
#              'longitude': 149.326,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 52,
#              'datetime': datetime.datetime(2021, 11, 30, 23, 25, 57),
#              'latitude': -37.635,
#              'longitude': 149.303,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#              'latitude': -37.59,
#              'longitude': 149.31,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#              'latitude': -37.633,
#              'longitude': 149.264,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#              'latitude': -37.58,
#              'longitude': 149.331,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 61,
#              'datetime': datetime.datetime(2021, 11, 30, 15, 38, 32),
#              'latitude': -37.38,
#              'longitude': 149.334,
#              'surface_temperature_celcius': 31}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#              'latitude': -37.602,
#              'longitude': 149.295,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#              'latitude': -37.598,
#              'longitude': 149.29,
#              'surface_temperature_celcius': 32}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#              'latitude': -37.61,
#              'longitude': 149.279,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 21),
#              'latitude': -37.637,
#              'longitude': 146.288,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#              'latitude': -37.6,
#              'longitude': 149.297,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 64,
#              'datetime': datetime.datetime(2021, 11, 30, 0, 20, 49),
#              'latitude': -37.382,
#              'longitude': 149.341,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 56,
#              'datetime': datetime.datetime(2021, 12, 8, 13, 11, 43),
#              'latitude': -36.291,
#              'longitude': 146.159,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 50,
#              'datetime': datetime.datetime(2021, 12, 10, 0, 57, 59),
#              'latitude': -37.987,
#              'longitude': 144.005,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 12, 10, 0, 56, 57),
#              'latitude': -34.289,
#              'longitude': 141.712,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 12, 12, 0, 45, 38),
#              'latitude': -37.903,
#              'longitude': 145.25,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 51,
#              'datetime': datetime.datetime(2021, 12, 15, 13, 17, 17),
#              'latitude': -37.623,
#              'longitude': 149.323,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 12, 15, 1, 16, 23),
#              'latitude': -38.038,
#              'longitude': 142.986,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 69,
#              'datetime': datetime.datetime(2021, 12, 16, 15, 38, 39),
#              'latitude': -37.624,
#              'longitude': 149.332,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 62,
#              'datetime': datetime.datetime(2021, 12, 16, 4, 35, 15),
#              'latitude': -37.82,
#              'longitude': 142.323,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 59,
#              'datetime': datetime.datetime(2021, 12, 16, 4, 34, 57),
#              'latitude': -37.644,
#              'longitude': 149.346,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 60,
#              'datetime': datetime.datetime(2021, 12, 16, 0, 21, 11),
#              'latitude': -38.046,
#              'longitude': 144.201,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 53,
#              'datetime': datetime.datetime(2021, 12, 16, 0, 20, 53),
#              'latitude': -37.63,
#              'longitude': 149.335,
#              'surface_temperature_celcius': 57}}
# {'hotspot': {'confidence': 65,
#              'datetime': datetime.datetime(2021, 12, 24, 13, 12, 1),
#              'latitude': -35.646,
#              'longitude': 142.282,
#              'surface_temperature_celcius': 32}}
# {'hotspot': {'confidence': 67,
#              'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#              'latitude': -35.554,
#              'longitude': 143.307,
#              'surface_temperature_celcius': 53}}

# %%
# 2.2h) Find the average surface temperature (°C) for each day. You are required to
# only display average surface temperature (°C) and the date in the output.

pipeline = [
    # don't have to flatten. we want to retain the data where there is no hotspot record
    
    {'$project': {'_id':False, 
                  "date":{ "$dateToString":{"format":"%d/%m/%Y", "date":"$date"}},
                  'avg_surface_temp': {'$avg':'$hotspot.surface_temperature_celcius'}}}
]

result = collection.aggregate(pipeline=pipeline)
print_cursor(result)
# Out:
# {'avg_surface_temp': None, 'date': '31/12/2020'}
# {'avg_surface_temp': None, 'date': '01/01/2021'}
# {'avg_surface_temp': None, 'date': '02/01/2021'}
# {'avg_surface_temp': None, 'date': '03/01/2021'}
# {'avg_surface_temp': None, 'date': '04/01/2021'}
# {'avg_surface_temp': None, 'date': '05/01/2021'}
# {'avg_surface_temp': None, 'date': '06/01/2021'}
# {'avg_surface_temp': None, 'date': '07/01/2021'}
# {'avg_surface_temp': None, 'date': '08/01/2021'}
# {'avg_surface_temp': None, 'date': '09/01/2021'}
# {'avg_surface_temp': None, 'date': '10/01/2021'}
# {'avg_surface_temp': None, 'date': '11/01/2021'}
# {'avg_surface_temp': None, 'date': '12/01/2021'}
# {'avg_surface_temp': None, 'date': '13/01/2021'}
# {'avg_surface_temp': None, 'date': '14/01/2021'}
# {'avg_surface_temp': None, 'date': '15/01/2021'}
# {'avg_surface_temp': None, 'date': '16/01/2021'}
# {'avg_surface_temp': None, 'date': '17/01/2021'}
# {'avg_surface_temp': None, 'date': '18/01/2021'}
# {'avg_surface_temp': None, 'date': '19/01/2021'}
# {'avg_surface_temp': None, 'date': '20/01/2021'}
# {'avg_surface_temp': None, 'date': '21/01/2021'}
# {'avg_surface_temp': None, 'date': '22/01/2021'}
# {'avg_surface_temp': None, 'date': '23/01/2021'}
# {'avg_surface_temp': None, 'date': '24/01/2021'}
# {'avg_surface_temp': None, 'date': '25/01/2021'}
# {'avg_surface_temp': None, 'date': '26/01/2021'}
# {'avg_surface_temp': None, 'date': '27/01/2021'}
# {'avg_surface_temp': None, 'date': '28/01/2021'}
# {'avg_surface_temp': None, 'date': '29/01/2021'}
# {'avg_surface_temp': None, 'date': '30/01/2021'}
# {'avg_surface_temp': None, 'date': '31/01/2021'}
# {'avg_surface_temp': None, 'date': '01/02/2021'}
# {'avg_surface_temp': None, 'date': '02/02/2021'}
# {'avg_surface_temp': None, 'date': '03/02/2021'}
# {'avg_surface_temp': None, 'date': '04/02/2021'}
# {'avg_surface_temp': None, 'date': '05/02/2021'}
# {'avg_surface_temp': None, 'date': '06/02/2021'}
# {'avg_surface_temp': None, 'date': '07/02/2021'}
# {'avg_surface_temp': None, 'date': '08/02/2021'}
# {'avg_surface_temp': None, 'date': '09/02/2021'}
# {'avg_surface_temp': None, 'date': '10/02/2021'}
# {'avg_surface_temp': None, 'date': '11/02/2021'}
# {'avg_surface_temp': None, 'date': '12/02/2021'}
# {'avg_surface_temp': None, 'date': '13/02/2021'}
# {'avg_surface_temp': None, 'date': '14/02/2021'}
# {'avg_surface_temp': None, 'date': '15/02/2021'}
# {'avg_surface_temp': None, 'date': '16/02/2021'}
# {'avg_surface_temp': None, 'date': '17/02/2021'}
# {'avg_surface_temp': None, 'date': '18/02/2021'}
# {'avg_surface_temp': None, 'date': '19/02/2021'}
# {'avg_surface_temp': None, 'date': '20/02/2021'}
# {'avg_surface_temp': None, 'date': '21/02/2021'}
# {'avg_surface_temp': None, 'date': '22/02/2021'}
# {'avg_surface_temp': None, 'date': '23/02/2021'}
# {'avg_surface_temp': None, 'date': '24/02/2021'}
# {'avg_surface_temp': None, 'date': '25/02/2021'}
# {'avg_surface_temp': None, 'date': '26/02/2021'}
# {'avg_surface_temp': None, 'date': '27/02/2021'}
# {'avg_surface_temp': None, 'date': '28/02/2021'}
# {'avg_surface_temp': None, 'date': '01/03/2021'}
# {'avg_surface_temp': None, 'date': '02/03/2021'}
# {'avg_surface_temp': None, 'date': '03/03/2021'}
# {'avg_surface_temp': None, 'date': '04/03/2021'}
# {'avg_surface_temp': None, 'date': '05/03/2021'}
# {'avg_surface_temp': 60.5, 'date': '06/03/2021'}
# {'avg_surface_temp': 64.0, 'date': '07/03/2021'}
# {'avg_surface_temp': 51.5, 'date': '08/03/2021'}
# {'avg_surface_temp': 46.666666666666664, 'date': '09/03/2021'}
# {'avg_surface_temp': 69.375, 'date': '10/03/2021'}
# {'avg_surface_temp': None, 'date': '11/03/2021'}
# {'avg_surface_temp': 88.2, 'date': '12/03/2021'}
# {'avg_surface_temp': 38.5, 'date': '13/03/2021'}
# {'avg_surface_temp': 65.6, 'date': '14/03/2021'}
# {'avg_surface_temp': 46.0, 'date': '15/03/2021'}
# {'avg_surface_temp': None, 'date': '16/03/2021'}
# {'avg_surface_temp': 59.5, 'date': '17/03/2021'}
# {'avg_surface_temp': 79.33333333333333, 'date': '18/03/2021'}
# {'avg_surface_temp': 65.57142857142857, 'date': '19/03/2021'}
# {'avg_surface_temp': None, 'date': '20/03/2021'}
# {'avg_surface_temp': None, 'date': '21/03/2021'}
# {'avg_surface_temp': None, 'date': '22/03/2021'}
# {'avg_surface_temp': None, 'date': '23/03/2021'}
# {'avg_surface_temp': 49.0, 'date': '24/03/2021'}
# {'avg_surface_temp': 66.0, 'date': '25/03/2021'}
# {'avg_surface_temp': 56.88235294117647, 'date': '26/03/2021'}
# {'avg_surface_temp': None, 'date': '27/03/2021'}
# {'avg_surface_temp': 60.925925925925924, 'date': '28/03/2021'}
# {'avg_surface_temp': 51.0, 'date': '29/03/2021'}
# {'avg_surface_temp': None, 'date': '30/03/2021'}
# {'avg_surface_temp': 48.72727272727273, 'date': '31/03/2021'}
# {'avg_surface_temp': 46.714285714285715, 'date': '01/04/2021'}
# {'avg_surface_temp': 45.2, 'date': '02/04/2021'}
# {'avg_surface_temp': 58.44444444444444, 'date': '03/04/2021'}
# {'avg_surface_temp': 62.57303370786517, 'date': '04/04/2021'}
# {'avg_surface_temp': 53.142857142857146, 'date': '05/04/2021'}
# {'avg_surface_temp': 61.71186440677966, 'date': '06/04/2021'}
# {'avg_surface_temp': 50.69230769230769, 'date': '07/04/2021'}
# {'avg_surface_temp': 60.75, 'date': '08/04/2021'}
# {'avg_surface_temp': None, 'date': '09/04/2021'}
# {'avg_surface_temp': None, 'date': '10/04/2021'}
# {'avg_surface_temp': 46.291666666666664, 'date': '11/04/2021'}
# {'avg_surface_temp': 52.69565217391305, 'date': '12/04/2021'}
# {'avg_surface_temp': 58.57983193277311, 'date': '13/04/2021'}
# {'avg_surface_temp': 61.94444444444444, 'date': '14/04/2021'}
# {'avg_surface_temp': 59.57971014492754, 'date': '15/04/2021'}
# {'avg_surface_temp': 48.72222222222222, 'date': '16/04/2021'}
# {'avg_surface_temp': 50.921052631578945, 'date': '17/04/2021'}
# {'avg_surface_temp': 53.36615384615384, 'date': '18/04/2021'}
# {'avg_surface_temp': 54.16, 'date': '19/04/2021'}
# {'avg_surface_temp': 56.58064516129032, 'date': '20/04/2021'}
# {'avg_surface_temp': None, 'date': '21/04/2021'}
# {'avg_surface_temp': 54.5, 'date': '22/04/2021'}
# {'avg_surface_temp': 53.89473684210526, 'date': '23/04/2021'}
# {'avg_surface_temp': 59.375, 'date': '24/04/2021'}
# {'avg_surface_temp': 48.666666666666664, 'date': '25/04/2021'}
# {'avg_surface_temp': 34.0, 'date': '26/04/2021'}
# {'avg_surface_temp': None, 'date': '27/04/2021'}
# {'avg_surface_temp': None, 'date': '28/04/2021'}
# {'avg_surface_temp': 63.0, 'date': '29/04/2021'}
# {'avg_surface_temp': None, 'date': '30/04/2021'}
# {'avg_surface_temp': 68.4, 'date': '01/05/2021'}
# {'avg_surface_temp': 55.6, 'date': '02/05/2021'}
# {'avg_surface_temp': 56.796875, 'date': '03/05/2021'}
# {'avg_surface_temp': 56.80740740740741, 'date': '04/05/2021'}
# {'avg_surface_temp': 51.70967741935484, 'date': '05/05/2021'}
# {'avg_surface_temp': 57.529411764705884, 'date': '06/05/2021'}
# {'avg_surface_temp': 50.333333333333336, 'date': '07/05/2021'}
# {'avg_surface_temp': 56.291666666666664, 'date': '08/05/2021'}
# {'avg_surface_temp': 42.46153846153846, 'date': '09/05/2021'}
# {'avg_surface_temp': 52.86842105263158, 'date': '10/05/2021'}
# {'avg_surface_temp': 59.36842105263158, 'date': '11/05/2021'}
# {'avg_surface_temp': 51.5, 'date': '12/05/2021'}
# {'avg_surface_temp': 58.611111111111114, 'date': '13/05/2021'}
# {'avg_surface_temp': 49.0, 'date': '14/05/2021'}
# {'avg_surface_temp': 53.950980392156865, 'date': '15/05/2021'}
# {'avg_surface_temp': 39.666666666666664, 'date': '16/05/2021'}
# {'avg_surface_temp': 52.0, 'date': '17/05/2021'}
# {'avg_surface_temp': 44.142857142857146, 'date': '18/05/2021'}
# {'avg_surface_temp': None, 'date': '19/05/2021'}
# {'avg_surface_temp': None, 'date': '20/05/2021'}
# {'avg_surface_temp': None, 'date': '21/05/2021'}
# {'avg_surface_temp': 54.484848484848484, 'date': '22/05/2021'}
# {'avg_surface_temp': 51.2, 'date': '23/05/2021'}
# {'avg_surface_temp': 40.333333333333336, 'date': '24/05/2021'}
# {'avg_surface_temp': None, 'date': '25/05/2021'}
# {'avg_surface_temp': 49.5, 'date': '26/05/2021'}
# {'avg_surface_temp': None, 'date': '27/05/2021'}
# {'avg_surface_temp': None, 'date': '28/05/2021'}
# {'avg_surface_temp': None, 'date': '29/05/2021'}
# {'avg_surface_temp': None, 'date': '30/05/2021'}
# {'avg_surface_temp': None, 'date': '31/05/2021'}
# {'avg_surface_temp': 54.0, 'date': '01/06/2021'}
# {'avg_surface_temp': 47.72727272727273, 'date': '02/06/2021'}
# {'avg_surface_temp': 47.0, 'date': '03/06/2021'}
# {'avg_surface_temp': 52.22222222222222, 'date': '04/06/2021'}
# {'avg_surface_temp': None, 'date': '05/06/2021'}
# {'avg_surface_temp': None, 'date': '06/06/2021'}
# {'avg_surface_temp': 51.857142857142854, 'date': '07/06/2021'}
# {'avg_surface_temp': None, 'date': '08/06/2021'}
# {'avg_surface_temp': 49.0, 'date': '09/06/2021'}
# {'avg_surface_temp': None, 'date': '10/06/2021'}
# {'avg_surface_temp': 41.5, 'date': '11/06/2021'}
# {'avg_surface_temp': None, 'date': '12/06/2021'}
# {'avg_surface_temp': 41.0, 'date': '13/06/2021'}
# {'avg_surface_temp': 53.25, 'date': '14/06/2021'}
# {'avg_surface_temp': None, 'date': '15/06/2021'}
# {'avg_surface_temp': 42.5, 'date': '16/06/2021'}
# {'avg_surface_temp': None, 'date': '17/06/2021'}
# {'avg_surface_temp': 42.0, 'date': '18/06/2021'}
# {'avg_surface_temp': None, 'date': '19/06/2021'}
# {'avg_surface_temp': 71.16666666666667, 'date': '20/06/2021'}
# {'avg_surface_temp': None, 'date': '21/06/2021'}
# {'avg_surface_temp': 46.0, 'date': '22/06/2021'}
# {'avg_surface_temp': None, 'date': '23/06/2021'}
# {'avg_surface_temp': None, 'date': '24/06/2021'}
# {'avg_surface_temp': None, 'date': '25/06/2021'}
# {'avg_surface_temp': None, 'date': '26/06/2021'}
# {'avg_surface_temp': None, 'date': '27/06/2021'}
# {'avg_surface_temp': None, 'date': '28/06/2021'}
# {'avg_surface_temp': None, 'date': '29/06/2021'}
# {'avg_surface_temp': 44.333333333333336, 'date': '30/06/2021'}
# {'avg_surface_temp': 30.5, 'date': '01/07/2021'}
# {'avg_surface_temp': 43.5, 'date': '02/07/2021'}
# {'avg_surface_temp': None, 'date': '03/07/2021'}
# {'avg_surface_temp': 40.0, 'date': '04/07/2021'}
# {'avg_surface_temp': 45.0, 'date': '05/07/2021'}
# {'avg_surface_temp': 56.0, 'date': '06/07/2021'}
# {'avg_surface_temp': None, 'date': '07/07/2021'}
# {'avg_surface_temp': None, 'date': '08/07/2021'}
# {'avg_surface_temp': None, 'date': '09/07/2021'}
# {'avg_surface_temp': None, 'date': '10/07/2021'}
# {'avg_surface_temp': None, 'date': '11/07/2021'}
# {'avg_surface_temp': None, 'date': '12/07/2021'}
# {'avg_surface_temp': None, 'date': '13/07/2021'}
# {'avg_surface_temp': 41.5, 'date': '14/07/2021'}
# {'avg_surface_temp': None, 'date': '15/07/2021'}
# {'avg_surface_temp': None, 'date': '16/07/2021'}
# {'avg_surface_temp': None, 'date': '17/07/2021'}
# {'avg_surface_temp': None, 'date': '18/07/2021'}
# {'avg_surface_temp': None, 'date': '19/07/2021'}
# {'avg_surface_temp': None, 'date': '20/07/2021'}
# {'avg_surface_temp': None, 'date': '21/07/2021'}
# {'avg_surface_temp': None, 'date': '22/07/2021'}
# {'avg_surface_temp': None, 'date': '23/07/2021'}
# {'avg_surface_temp': None, 'date': '24/07/2021'}
# {'avg_surface_temp': None, 'date': '25/07/2021'}
# {'avg_surface_temp': None, 'date': '26/07/2021'}
# {'avg_surface_temp': None, 'date': '27/07/2021'}
# {'avg_surface_temp': None, 'date': '28/07/2021'}
# {'avg_surface_temp': 48.0, 'date': '29/07/2021'}
# {'avg_surface_temp': None, 'date': '30/07/2021'}
# {'avg_surface_temp': 47.0, 'date': '31/07/2021'}
# {'avg_surface_temp': 58.0, 'date': '01/08/2021'}
# {'avg_surface_temp': 63.5, 'date': '02/08/2021'}
# {'avg_surface_temp': None, 'date': '03/08/2021'}
# {'avg_surface_temp': None, 'date': '04/08/2021'}
# {'avg_surface_temp': 40.0, 'date': '05/08/2021'}
# {'avg_surface_temp': None, 'date': '06/08/2021'}
# {'avg_surface_temp': None, 'date': '07/08/2021'}
# {'avg_surface_temp': None, 'date': '08/08/2021'}
# {'avg_surface_temp': None, 'date': '09/08/2021'}
# {'avg_surface_temp': 63.0, 'date': '10/08/2021'}
# {'avg_surface_temp': None, 'date': '11/08/2021'}
# {'avg_surface_temp': None, 'date': '12/08/2021'}
# {'avg_surface_temp': 49.0, 'date': '13/08/2021'}
# {'avg_surface_temp': 40.8, 'date': '14/08/2021'}
# {'avg_surface_temp': None, 'date': '15/08/2021'}
# {'avg_surface_temp': None, 'date': '16/08/2021'}
# {'avg_surface_temp': None, 'date': '17/08/2021'}
# {'avg_surface_temp': None, 'date': '18/08/2021'}
# {'avg_surface_temp': None, 'date': '19/08/2021'}
# {'avg_surface_temp': None, 'date': '20/08/2021'}
# {'avg_surface_temp': None, 'date': '21/08/2021'}
# {'avg_surface_temp': None, 'date': '22/08/2021'}
# {'avg_surface_temp': None, 'date': '23/08/2021'}
# {'avg_surface_temp': None, 'date': '24/08/2021'}
# {'avg_surface_temp': None, 'date': '25/08/2021'}
# {'avg_surface_temp': None, 'date': '26/08/2021'}
# {'avg_surface_temp': None, 'date': '27/08/2021'}
# {'avg_surface_temp': None, 'date': '28/08/2021'}
# {'avg_surface_temp': None, 'date': '29/08/2021'}
# {'avg_surface_temp': None, 'date': '30/08/2021'}
# {'avg_surface_temp': None, 'date': '31/08/2021'}
# {'avg_surface_temp': None, 'date': '01/09/2021'}
# {'avg_surface_temp': None, 'date': '02/09/2021'}
# {'avg_surface_temp': None, 'date': '03/09/2021'}
# {'avg_surface_temp': None, 'date': '04/09/2021'}
# {'avg_surface_temp': None, 'date': '05/09/2021'}
# {'avg_surface_temp': None, 'date': '06/09/2021'}
# {'avg_surface_temp': None, 'date': '07/09/2021'}
# {'avg_surface_temp': None, 'date': '08/09/2021'}
# {'avg_surface_temp': None, 'date': '09/09/2021'}
# {'avg_surface_temp': 56.5, 'date': '10/09/2021'}
# {'avg_surface_temp': None, 'date': '11/09/2021'}
# {'avg_surface_temp': None, 'date': '12/09/2021'}
# {'avg_surface_temp': None, 'date': '13/09/2021'}
# {'avg_surface_temp': None, 'date': '14/09/2021'}
# {'avg_surface_temp': None, 'date': '15/09/2021'}
# {'avg_surface_temp': None, 'date': '16/09/2021'}
# {'avg_surface_temp': None, 'date': '17/09/2021'}
# {'avg_surface_temp': None, 'date': '18/09/2021'}
# {'avg_surface_temp': None, 'date': '19/09/2021'}
# {'avg_surface_temp': 63.6, 'date': '20/09/2021'}
# {'avg_surface_temp': 40.5, 'date': '21/09/2021'}
# {'avg_surface_temp': 45.0, 'date': '22/09/2021'}
# {'avg_surface_temp': 52.73913043478261, 'date': '23/09/2021'}
# {'avg_surface_temp': 53.57142857142857, 'date': '24/09/2021'}
# {'avg_surface_temp': None, 'date': '25/09/2021'}
# {'avg_surface_temp': 33.0, 'date': '26/09/2021'}
# {'avg_surface_temp': 49.714285714285715, 'date': '27/09/2021'}
# {'avg_surface_temp': None, 'date': '28/09/2021'}
# {'avg_surface_temp': 43.0, 'date': '29/09/2021'}
# {'avg_surface_temp': None, 'date': '30/09/2021'}
# {'avg_surface_temp': 48.25, 'date': '01/10/2021'}
# {'avg_surface_temp': 43.57142857142857, 'date': '02/10/2021'}
# {'avg_surface_temp': 50.0, 'date': '03/10/2021'}
# {'avg_surface_temp': 49.0, 'date': '04/10/2021'}
# {'avg_surface_temp': None, 'date': '05/10/2021'}
# {'avg_surface_temp': 44.0, 'date': '06/10/2021'}
# {'avg_surface_temp': 42.0, 'date': '07/10/2021'}
# {'avg_surface_temp': 41.0, 'date': '08/10/2021'}
# {'avg_surface_temp': 44.0, 'date': '09/10/2021'}
# {'avg_surface_temp': 53.333333333333336, 'date': '10/10/2021'}
# {'avg_surface_temp': None, 'date': '11/10/2021'}
# {'avg_surface_temp': None, 'date': '12/10/2021'}
# {'avg_surface_temp': None, 'date': '13/10/2021'}
# {'avg_surface_temp': None, 'date': '14/10/2021'}
# {'avg_surface_temp': 72.66666666666667, 'date': '15/10/2021'}
# {'avg_surface_temp': 36.0, 'date': '16/10/2021'}
# {'avg_surface_temp': 51.6, 'date': '17/10/2021'}
# {'avg_surface_temp': 52.166666666666664, 'date': '18/10/2021'}
# {'avg_surface_temp': None, 'date': '19/10/2021'}
# {'avg_surface_temp': 50.0, 'date': '20/10/2021'}
# {'avg_surface_temp': 51.25, 'date': '21/10/2021'}
# {'avg_surface_temp': None, 'date': '22/10/2021'}
# {'avg_surface_temp': 38.0, 'date': '23/10/2021'}
# {'avg_surface_temp': None, 'date': '24/10/2021'}
# {'avg_surface_temp': None, 'date': '25/10/2021'}
# {'avg_surface_temp': 44.6, 'date': '26/10/2021'}
# {'avg_surface_temp': 50.4, 'date': '27/10/2021'}
# {'avg_surface_temp': 56.0, 'date': '28/10/2021'}
# {'avg_surface_temp': None, 'date': '29/10/2021'}
# {'avg_surface_temp': None, 'date': '30/10/2021'}
# {'avg_surface_temp': None, 'date': '31/10/2021'}
# {'avg_surface_temp': None, 'date': '01/11/2021'}
# {'avg_surface_temp': None, 'date': '02/11/2021'}
# {'avg_surface_temp': None, 'date': '03/11/2021'}
# {'avg_surface_temp': None, 'date': '04/11/2021'}
# {'avg_surface_temp': 58.5, 'date': '05/11/2021'}
# {'avg_surface_temp': None, 'date': '06/11/2021'}
# {'avg_surface_temp': None, 'date': '07/11/2021'}
# {'avg_surface_temp': 45.5, 'date': '08/11/2021'}
# {'avg_surface_temp': 61.3, 'date': '09/11/2021'}
# {'avg_surface_temp': None, 'date': '10/11/2021'}
# {'avg_surface_temp': 46.25, 'date': '11/11/2021'}
# {'avg_surface_temp': 53.0, 'date': '12/11/2021'}
# {'avg_surface_temp': 47.0, 'date': '13/11/2021'}
# {'avg_surface_temp': 52.0, 'date': '14/11/2021'}
# {'avg_surface_temp': None, 'date': '15/11/2021'}
# {'avg_surface_temp': None, 'date': '16/11/2021'}
# {'avg_surface_temp': None, 'date': '17/11/2021'}
# {'avg_surface_temp': None, 'date': '18/11/2021'}
# {'avg_surface_temp': None, 'date': '19/11/2021'}
# {'avg_surface_temp': None, 'date': '20/11/2021'}
# {'avg_surface_temp': 59.0, 'date': '21/11/2021'}
# {'avg_surface_temp': 61.5, 'date': '22/11/2021'}
# {'avg_surface_temp': 58.8, 'date': '23/11/2021'}
# {'avg_surface_temp': None, 'date': '24/11/2021'}
# {'avg_surface_temp': None, 'date': '25/11/2021'}
# {'avg_surface_temp': None, 'date': '26/11/2021'}
# {'avg_surface_temp': None, 'date': '27/11/2021'}
# {'avg_surface_temp': 42.0, 'date': '28/11/2021'}
# {'avg_surface_temp': 60.625, 'date': '29/11/2021'}
# {'avg_surface_temp': 52.41935483870968, 'date': '30/11/2021'}
# {'avg_surface_temp': None, 'date': '01/12/2021'}
# {'avg_surface_temp': None, 'date': '02/12/2021'}
# {'avg_surface_temp': None, 'date': '03/12/2021'}
# {'avg_surface_temp': None, 'date': '04/12/2021'}
# {'avg_surface_temp': None, 'date': '05/12/2021'}
# {'avg_surface_temp': None, 'date': '06/12/2021'}
# {'avg_surface_temp': None, 'date': '07/12/2021'}
# {'avg_surface_temp': 50.6, 'date': '08/12/2021'}
# {'avg_surface_temp': 58.25, 'date': '09/12/2021'}
# {'avg_surface_temp': 46.0, 'date': '10/12/2021'}
# {'avg_surface_temp': None, 'date': '11/12/2021'}
# {'avg_surface_temp': 44.0, 'date': '12/12/2021'}
# {'avg_surface_temp': 60.0, 'date': '13/12/2021'}
# {'avg_surface_temp': 70.0, 'date': '14/12/2021'}
# {'avg_surface_temp': 39.0, 'date': '15/12/2021'}
# {'avg_surface_temp': 57.8, 'date': '16/12/2021'}
# {'avg_surface_temp': None, 'date': '17/12/2021'}
# {'avg_surface_temp': None, 'date': '18/12/2021'}
# {'avg_surface_temp': None, 'date': '19/12/2021'}
# {'avg_surface_temp': None, 'date': '20/12/2021'}
# {'avg_surface_temp': 46.0, 'date': '21/12/2021'}
# {'avg_surface_temp': None, 'date': '22/12/2021'}
# {'avg_surface_temp': None, 'date': '23/12/2021'}
# {'avg_surface_temp': 32.0, 'date': '24/12/2021'}
# {'avg_surface_temp': 54.0, 'date': '25/12/2021'}
# {'avg_surface_temp': None, 'date': '26/12/2021'}
# {'avg_surface_temp': 62.75, 'date': '27/12/2021'}
# {'avg_surface_temp': None, 'date': '28/12/2021'}
# {'avg_surface_temp': None, 'date': '29/12/2021'}
# {'avg_surface_temp': None, 'date': '30/12/2021'}
# {'avg_surface_temp': None, 'date': '31/12/2021'}

# %%
# 2.2i) Find the top 10 records with the lowest GHI.

# don't have to aggregate because we can directly sort by GHI
result = collection.find().sort('GHI', pymongo.ASCENDING).limit(10)

print_cursor(result)
# Out:
# {'GHI': 47,
#  '_id': ObjectId('628292f65b3178ab2dccecd1'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2021, 8, 2, 0, 0),
#  'hotspot': [{'confidence': 94,
#               'datetime': datetime.datetime(2021, 8, 2, 3, 45, 40),
#               'latitude': -37.4796,
#               'longitude': 141.9403,
#               'surface_temperature_celcius': 87},
#              {'confidence': 54,
#               'datetime': datetime.datetime(2021, 8, 2, 3, 45),
#               'latitude': -37.491,
#               'longitude': 141.936,
#               'surface_temperature_celcius': 40}],
#  'max_wind_speed': 5.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI': 48,
#  '_id': ObjectId('628292f65b3178ab2dccecb0'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2021, 6, 30, 0, 0),
#  'hotspot': [{'confidence': 78,
#               'datetime': datetime.datetime(2021, 6, 30, 4, 41, 25),
#               'latitude': -36.834,
#               'longitude': 142.524,
#               'surface_temperature_celcius': 44},
#              {'confidence': 78,
#               'datetime': datetime.datetime(2021, 6, 30, 4, 41, 25),
#               'latitude': -36.834,
#               'longitude': 142.524,
#               'surface_temperature_celcius': 44},
#              {'confidence': 81,
#               'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#               'latitude': -37.858,
#               'longitude': 143.428,
#               'surface_temperature_celcius': 48},
#              {'confidence': 75,
#               'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#               'latitude': -37.856,
#               'longitude': 143.416,
#               'surface_temperature_celcius': 41},
#              {'confidence': 75,
#               'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#               'latitude': -37.856,
#               'longitude': 143.416,
#               'surface_temperature_celcius': 41},
#              {'confidence': 81,
#               'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#               'latitude': -37.858,
#               'longitude': 143.428,
#               'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI': 49,
#  '_id': ObjectId('628292f65b3178ab2dccecb1'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2021, 7, 1, 0, 0),
#  'hotspot': [{'confidence': 53,
#               'datetime': datetime.datetime(2021, 7, 1, 13, 11, 41),
#               'latitude': -37.062,
#               'longitude': 141.373,
#               'surface_temperature_celcius': 29},
#              {'confidence': 53,
#               'datetime': datetime.datetime(2021, 7, 1, 13, 11, 41),
#               'latitude': -37.062,
#               'longitude': 141.373,
#               'surface_temperature_celcius': 29},
#              {'confidence': 61,
#               'datetime': datetime.datetime(2021, 7, 1, 3, 46, 8),
#               'latitude': -36.779,
#               'longitude': 146.108,
#               'surface_temperature_celcius': 32},
#              {'confidence': 61,
#               'datetime': datetime.datetime(2021, 7, 1, 3, 46, 8),
#               'latitude': -36.779,
#               'longitude': 146.108,
#               'surface_temperature_celcius': 32}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI': 56,
#  '_id': ObjectId('628292f65b3178ab2dccecbb'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2021, 7, 11, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 5.1,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI': 57,
#  '_id': ObjectId('628292f65b3178ab2dccecbf'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2021, 7, 15, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI': 60,
#  '_id': ObjectId('628292f65b3178ab2dccecb2'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2021, 7, 2, 0, 0),
#  'hotspot': [{'confidence': 84,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 29, 18),
#               'latitude': -36.397,
#               'longitude': 142.254,
#               'surface_temperature_celcius': 52},
#              {'confidence': 84,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 29, 18),
#               'latitude': -36.397,
#               'longitude': 142.254,
#               'surface_temperature_celcius': 52},
#              {'confidence': 69,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 29, 10),
#               'latitude': -37.067,
#               'longitude': 141.379,
#               'surface_temperature_celcius': 36},
#              {'confidence': 69,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 29, 10),
#               'latitude': -37.067,
#               'longitude': 141.379,
#               'surface_temperature_celcius': 36},
#              {'confidence': 88,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 29),
#               'latitude': -37.333,
#               'longitude': 143.534,
#               'surface_temperature_celcius': 58},
#              {'confidence': 88,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 29),
#               'latitude': -37.333,
#               'longitude': 143.534,
#               'surface_temperature_celcius': 58},
#              {'confidence': 50,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 28, 42),
#               'latitude': -37.886,
#               'longitude': 147.207,
#               'surface_temperature_celcius': 28},
#              {'confidence': 50,
#               'datetime': datetime.datetime(2021, 7, 2, 4, 28, 42),
#               'latitude': -37.886,
#               'longitude': 147.207,
#               'surface_temperature_celcius': 28}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI': 65,
#  '_id': ObjectId('628292f65b3178ab2dccecd0'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 8, 1, 0, 0),
#  'hotspot': [{'confidence': 89,
#               'datetime': datetime.datetime(2021, 8, 1, 0, 20, 30),
#               'latitude': -38.3998,
#               'longitude': 147.064,
#               'surface_temperature_celcius': 65},
#              {'confidence': 78,
#               'datetime': datetime.datetime(2021, 8, 1, 0, 19, 30),
#               'latitude': -38.3982,
#               'longitude': 147.0509,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI': 65,
#  '_id': ObjectId('628292f65b3178ab2dcceccf'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 7, 31, 0, 0),
#  'hotspot': [{'confidence': 100,
#               'datetime': datetime.datetime(2021, 7, 31, 13, 21),
#               'latitude': -37.8641,
#               'longitude': 143.4276,
#               'surface_temperature_celcius': 51},
#              {'confidence': 92,
#               'datetime': datetime.datetime(2021, 7, 31, 13, 21),
#               'latitude': -37.8658,
#               'longitude': 143.4162,
#               'surface_temperature_celcius': 43}],
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI': 65,
#  '_id': ObjectId('628292f65b3178ab2dccecc4'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 7, 20, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI': 66,
#  '_id': ObjectId('628292f65b3178ab2dccece2'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 8, 19, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %%
# 2.2j) Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.

# 24-hour precipitation -> precipitation flag = G
query = {'$and':[
        {'precipitation_flag': {'$in':['D', 'F', 'G']}},
        {'precipitation': {"$gte": 0.20, "$lte": 0.35}}
    ]}

result = collection.find(query)

print_cursor(result)
# Out:
# {'GHI': 157,
#  '_id': ObjectId('628292f65b3178ab2dccec08'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 1, 13, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI': 146,
#  '_id': ObjectId('628292f65b3178ab2dccec53'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2021, 3, 29, 0, 0),
#  'hotspot': [{'confidence': 69,
#               'datetime': datetime.datetime(2021, 3, 29, 0, 48, 40),
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI': 166,
#  '_id': ObjectId('628292f65b3178ab2dccec69'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2021, 4, 20, 0, 0),
#  'hotspot': [{'confidence': 84,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 44, 20),
#               'latitude': -36.8871,
#               'longitude': 145.1536,
#               'surface_temperature_celcius': 58},
#              {'confidence': 59,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 36),
#               'latitude': -38.4685,
#               'longitude': 146.673,
#               'surface_temperature_celcius': 40},
#              {'confidence': 60,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 34, 10),
#               'latitude': -36.8922,
#               'longitude': 145.1252,
#               'surface_temperature_celcius': 40},
#              {'confidence': 93,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 34, 10),
#               'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celcius': 72},
#              {'confidence': 77,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 33, 40),
#               'latitude': -36.0799,
#               'longitude': 146.0784,
#               'surface_temperature_celcius': 50},
#              {'confidence': 88,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 33, 20),
#               'latitude': -36.0829,
#               'longitude': 146.0621,
#               'surface_temperature_celcius': 63},
#              {'confidence': 90,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 50),
#               'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celcius': 67},
#              {'confidence': 67,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 50),
#               'latitude': -37.7615,
#               'longitude': 147.9169,
#               'surface_temperature_celcius': 45},
#              {'confidence': 63,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.8079,
#               'longitude': 145.1409,
#               'surface_temperature_celcius': 42},
#              {'confidence': 85,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -37.7783,
#               'longitude': 147.9284,
#               'surface_temperature_celcius': 60},
#              {'confidence': 79,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.8846,
#               'longitude': 145.1679,
#               'surface_temperature_celcius': 52},
#              {'confidence': 80,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -37.2341,
#               'longitude': 149.1736,
#               'surface_temperature_celcius': 53},
#              {'confidence': 63,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.9189,
#               'longitude': 147.5603,
#               'surface_temperature_celcius': 52},
#              {'confidence': 98,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celcius': 84},
#              {'confidence': 87,
#               'datetime': datetime.datetime(2021, 4, 20, 4, 32, 30),
#               'latitude': -36.9246,
#               'longitude': 147.5559,
#               'surface_temperature_celcius': 62},
#              {'confidence': 64,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 19),
#               'latitude': -36.085,
#               'longitude': 145.9096,
#               'surface_temperature_celcius': 42},
#              {'confidence': 88,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 18, 40),
#               'latitude': -38.1301,
#               'longitude': 143.9398,
#               'surface_temperature_celcius': 63},
#              {'confidence': 69,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 18, 20),
#               'latitude': -37.7087,
#               'longitude': 145.5499,
#               'surface_temperature_celcius': 45},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 18, 20),
#               'latitude': -36.5865,
#               'longitude': 145.2081,
#               'surface_temperature_celcius': 111},
#              {'confidence': 73,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 17, 10),
#               'latitude': -36.8702,
#               'longitude': 144.0381,
#               'surface_temperature_celcius': 47},
#              {'confidence': 99,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 17, 10),
#               'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celcius': 85},
#              {'confidence': 74,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 16, 50),
#               'latitude': -37.8672,
#               'longitude': 143.8194,
#               'surface_temperature_celcius': 48},
#              {'confidence': 78,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 15, 30),
#               'latitude': -36.5956,
#               'longitude': 145.206,
#               'surface_temperature_celcius': 51},
#              {'confidence': 77,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 14, 20),
#               'latitude': -37.2197,
#               'longitude': 148.8134,
#               'surface_temperature_celcius': 50},
#              {'confidence': 96,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 14, 10),
#               'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celcius': 78},
#              {'confidence': 89,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13, 40),
#               'latitude': -37.6997,
#               'longitude': 145.5519,
#               'surface_temperature_celcius': 64},
#              {'confidence': 61,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13, 30),
#               'latitude': -37.932,
#               'longitude': 146.1845,
#               'surface_temperature_celcius': 50},
#              {'confidence': 76,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13, 10),
#               'latitude': -36.6407,
#               'longitude': 144.2957,
#               'surface_temperature_celcius': 50},
#              {'confidence': 63,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13),
#               'latitude': -36.1569,
#               'longitude': 145.6554,
#               'surface_temperature_celcius': 41},
#              {'confidence': 54,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 13),
#               'latitude': -36.6363,
#               'longitude': 144.3033,
#               'surface_temperature_celcius': 40},
#              {'confidence': 76,
#               'datetime': datetime.datetime(2021, 4, 20, 0, 12, 50),
#               'latitude': -37.2212,
#               'longitude': 148.8262,
#               'surface_temperature_celcius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI': 102,
#  '_id': ObjectId('628292f65b3178ab2dccec6f'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 4, 26, 0, 0),
#  'hotspot': [{'confidence': 56,
#               'datetime': datetime.datetime(2021, 4, 26, 13, 26, 10),
#               'latitude': -36.5511,
#               'longitude': 146.7819,
#               'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI': 122,
#  '_id': ObjectId('628292f65b3178ab2dccec8e'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2021, 5, 27, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.35,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI': 73,
#  '_id': ObjectId('628292f65b3178ab2dccec91'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2021, 5, 30, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI': 98,
#  '_id': ObjectId('628292f65b3178ab2dccecb3'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 7, 3, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI': 99,
#  '_id': ObjectId('628292f65b3178ab2dcceccb'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 7, 27, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI': 83,
#  '_id': ObjectId('628292f65b3178ab2dccecd5'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2021, 8, 6, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI': 102,
#  '_id': ObjectId('628292f65b3178ab2dccece9'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 8, 26, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI': 75,
#  '_id': ObjectId('628292f65b3178ab2dccecf3'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2021, 9, 5, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI': 90,
#  '_id': ObjectId('628292f65b3178ab2dccecf5'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2021, 9, 7, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI': 97,
#  '_id': ObjectId('628292f65b3178ab2dccecfd'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 9, 15, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI': 105,
#  '_id': ObjectId('628292f65b3178ab2dcced11'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2021, 10, 5, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI': 152,
#  '_id': ObjectId('628292f65b3178ab2dcced29'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2021, 10, 29, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 27.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI': 100,
#  '_id': ObjectId('628292f65b3178ab2dcced2a'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 10, 30, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI': 140,
#  '_id': ObjectId('628292f65b3178ab2dcced3b'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 11, 16, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI': 151,
#  '_id': ObjectId('628292f65b3178ab2dcced3c'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 11, 17, 0, 0),
#  'hotspot': [],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI': 202,
#  '_id': ObjectId('628292f65b3178ab2dcced49'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'hotspot': [{'confidence': 52,
#               'datetime': datetime.datetime(2021, 11, 30, 23, 25, 57),
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#              {'confidence': 51,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42},
#              {'confidence': 64,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#              {'confidence': 69,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#              {'confidence': 61,
#               'datetime': datetime.datetime(2021, 11, 30, 15, 38, 32),
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31},
#              {'confidence': 62,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33},
#              {'confidence': 64,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32},
#              {'confidence': 84,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38},
#              {'confidence': 81,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.63,
#               'longitude': 149.232,
#               'surface_temperature_celcius': 42},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.644,
#               'longitude': 149.233,
#               'surface_temperature_celcius': 55},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#               'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65},
#              {'confidence': 100,
#               'datetime': datetime.datetime(2021, 11, 30, 12, 22, 14),
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71},
#              {'confidence': 84,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#               'latitude': -37.384,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 59},
#              {'confidence': 73,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#               'latitude': -37.389,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 50},
#              {'confidence': 98,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83},
#              {'confidence': 81,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.627,
#               'longitude': 149.261,
#               'surface_temperature_celcius': 57},
#              {'confidence': 84,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.623,
#               'longitude': 149.284,
#               'surface_temperature_celcius': 61},
#              {'confidence': 99,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86},
#              {'confidence': 69,
#               'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48},
#              {'confidence': 60,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 21),
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42},
#              {'confidence': 83,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.608,
#               'longitude': 149.282,
#               'surface_temperature_celcius': 58},
#              {'confidence': 87,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.62,
#               'longitude': 149.294,
#               'surface_temperature_celcius': 63},
#              {'confidence': 95,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76},
#              {'confidence': 81,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.61,
#               'longitude': 149.296,
#               'surface_temperature_celcius': 56},
#              {'confidence': 73,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.603,
#               'longitude': 149.324,
#               'surface_temperature_celcius': 51},
#              {'confidence': 81,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.602,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 55},
#              {'confidence': 69,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50},
#              {'confidence': 64,
#               'datetime': datetime.datetime(2021, 11, 30, 0, 20, 49),
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
